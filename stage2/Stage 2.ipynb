# %% [markdown]
# # Stage 2 - extracting structured information from raw data

# %% [markdown]
# In this stage of the project, our goals are to 1) develop an extractor that achieves at least precision of 90% or higher and as high recall as possible, but at least 50% in recall, 2) get practice with cross-validation
#
# Our data sources can be found on the main *readme.md* of this GitHub folder. We have gone through and tagged positive and negative examples in our raw data. Our objective is to properly extract movie titles from movie reviews. Our pre-processing steps included extracting the body of the text from the raw html files. From there we developed a unique tag which we used to label positive examples.
#
# We split up our data into three sets: set 1, set2, set 3. We designate set 3 as our final testing set.
#
# We start with set 1. Based on the positive examples and trends we identified during the labeling of positive examples, we generate features. We then run k-fold CV on set 1 using a selection of classifiers (Decision Tree, Logisitc, SVM, Random Forest, Extra Trees). Here we identify baseline precision, recall, and F1.
#
# We then test this on set 2 and explore false negative and false positives in set 2. Based on these, we modify our rules/features. We then re-run k-fold CV on set 1. We do this iteratively. Once we see an improvement in set1, we finally test on set 3 and report the results as well as our best-performing classifier.

# %%
#Import Necessary Modules
import os
import sys
import re
import time
import shutil
import collections
import pandas as pd
from sklearn import tree
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
import scipy
import matplotlib
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import linear_model
from sklearn.ensemble import ExtraTreesClassifier
from sklearn import svm
from sklearn.model_selection import KFold
import random

# %% [markdown]
# ## Importing Data and Feature Generation

# %% [markdown]
# ### Importing Data

# %%
def exampleGen(newpath):
    # max number of words to get before and after the title
    MAXWORDS = 3
    # max number of negtive examples from each document
    MAXNEG = 10
    # max number of words in negtive examples
    MAXNEGWORDS = 3

    # output list of examples for feature generation
    # use this as the input of feature generation
    # format: (title, wordsbefore, wordsafter, class)
    outlist = []
    exid = 0
    ouputfile = open("examples.txt",'w')

    pos_num = 0
    neg_num = 0
    badfile_num = 0
    file_num = 0

    # path to the html folder
    
    files = os.listdir(newpath)
    for file in files:
        with open(newpath+file) as f:

            file_num += 1
            # wrap all lines without new line charactar
            lines=""
            for line in f:
                lines += line.strip()
            words = lines.split(" ")

            title = ""
            within = False
            wordsprocessed = []
            badfile = False
            for i in range(len(words)):
                tmplist = []
                word = words[i]
                if word == '': continue
                
                pos1 = word.find("<myy>")
                pos2 = word.find("</myy>")
                # if no tag found
                if pos1 == -1 and pos2 == -1:
                    wordsprocessed.append((word,within))
                # if both are found
                if pos1 >= 0 and pos2 >= 0:
                    tmplist = word.split("<myy>")
                    if len(tmplist)>2 or pos2 < pos1:
                        badfile = True
                        break
                    if tmplist[0]!='':
                        wordsprocessed.append((tmplist[0],within))
                    within = True
                    tmplist = tmplist[1].split("</myy>")
                    wordsprocessed.append((tmplist[0],within))
                    within = False
                    if tmplist[1]!='':
                        wordsprocessed.append((tmplist[1],within))
                    continue
                # if only start tag
                if pos1 >= 0:
                    tmplist = word.split("<myy>")
                    if len(tmplist)>2:
                        badfile = True
                        break
                    if tmplist[0]!='':
                        wordsprocessed.append((tmplist[0],within))
                    within = True
                    wordsprocessed.append((tmplist[1],within))
                    continue
                # if only end tag
                if pos2 >= 0:
                    tmplist = word.split("</myy>")
                    if len(tmplist)>2:
                        badfile = True
                        break
                    wordsprocessed.append((tmplist[0],within))
                    within = False
                    if tmplist[1]!='':
                        wordsprocessed.append((tmplist[1],within))

            if badfile is True:
                badfile_num += 1
                continue

            # get positive examples from the processed words
            wordsbefore = []
            wordsafter = []
            title = ""
            for i in range(len(wordsprocessed)):
                item = wordsprocessed[i]
                if item[1] is True:
                    # if it is the first word
                    if i == 0:
                        title += item[0]
                        while len(wordsbefore) < MAXWORDS:
                            wordsbefore.append("")
                    # if word before is also title
                    elif wordsprocessed[i-1][1]:
                        title += " " + item[0]
                    else:
                        title += item[0]
                        # get words before the title
                        for j in range(i-1,i-1-MAXWORDS,-1):
                            if j >= 0:
                                wordsbefore.append(wordsprocessed[j][0])
                            else:
                                # add empty element
                                while len(wordsbefore) < MAXWORDS:
                                    wordsbefore.append("")
                                break
                else:
                    # if the word before this is title
                    if i != 0 and wordsprocessed[i-1][1]:
                        # get words after the title
                        for j in range(i,i+MAXWORDS):
                            if j < len(wordsprocessed):
                                wordsafter.append(wordsprocessed[j][0])
                            else:
                                # add empty element
                                while len(wordsafter) < MAXWORDS:
                                    wordsafter.append("")
                                break
                        # add title and words before and after to output list
                        featuretuple = (exid,title, wordsbefore, wordsafter, True)
                        #print(featuretuple)
                        outlist.append(featuretuple)
                        exid += 1

                        # generate output string
                        # this part can be skipped if only want features
                        outstr = title + ", ["
                        for w in wordsbefore:
                            if w is None:
                                outstr += 'None '
                            else:
                                outstr += w + ' '
                        outstr += '], ['
                        for w in wordsafter:
                            if w is None:
                                outstr += 'None '
                            else:
                                outstr += w + ' '
                        outstr += '], T\n'
                        ouputfile.write(outstr)

                        pos_num += 1

                        title = ""
                        wordsbefore = []
                        wordsafter = []

            # get negtive examples
            wordsbefore = []
            wordsafter = []
            title = ""
            count = 0
            poslist = []
            # skip the document if there are not enough words in it
            if len(wordsprocessed) < 100:
                continue
            while count < MAXNEG:
                pos = random.randint(MAXWORDS+1, len(wordsprocessed)-MAXWORDS-MAXNEGWORDS)
                title_len = random.randint(1,MAXNEGWORDS)
                # get neg title
                alltrue = True
                for i in range(title_len):
                    if wordsprocessed[pos+i][1] is False:
                        alltrue = False
                    title += wordsprocessed[pos+i][0] + " "
                # if all words are in title
                if alltrue is True:
                    title = ""
                    continue
                title = title.strip()
                # get words before and after
                for i in range(0,MAXWORDS):
                    wordsbefore.append(wordsprocessed[pos-i-1][0])
                    wordsafter.append(wordsprocessed[pos+title_len+i][0])
                featuretuple = (exid,title, wordsbefore, wordsafter, False)
                #print(featuretuple)
                outlist.append(featuretuple)
                exid += 1

                # generate output string
                # this part can be skipped if only want features
                outstr = title + ", ["
                for w in wordsbefore:
                    if w is None:
                        outstr += 'None '
                    else:
                        outstr += w + ' '
                outstr += '], ['
                for w in wordsafter:
                    if w is None:
                        outstr += 'None '
                    else:
                        outstr += w + ' '
                outstr += '], F\n'
                ouputfile.write(outstr)


                neg_num += 1
                count += 1
                title=""
                wordsbefore = []
                wordsafter = []

    ouputfile.close()
    return outlist

# %%
path_set1 = '../../DataforProject/reviews/Yuying_tagged/'
path_set2 = '../../DataforProject/reviews/Maria_tagged/'
path_set3 = '../../DataforProject/reviews/Young_tagged/'

# %%
set1 = exampleGen(path_set1)
set2 = exampleGen(path_set2)
set3 = exampleGen(path_set3)

# %%
#Explore the set
set1[0:10]
# Out:
# [(0, 'LITTLE WOMEN', ['', '', ''], ['A', 'film', 'review'], True),
#  (1,
#   'LITTLE WOMEN',
#   ['1868', "Alcott's", 'LousiaMay'],
#   [',', 'based', 'in'],
#   True),
#  (2,
#   'MY BRILLIANT CAREER',
#   ['of', 'Armstrong', 'Gillian'],
#   ['and', 'MRS.', 'SOFFEL'],
#   True),
#  (3,
#   'MRS. SOFFEL',
#   ['and', 'CAREER', 'BRILLIANT'],
#   ['.', 'The', 'Marches'],
#   True),
#  (4,
#   'INTERVIEW WITH THE VAMPIRE',
#   ['from', 'child', 'a'],
#   ['.', 'Among', 'other'],
#   True),
#  (5,
#   'LITTLE WOMEN',
#   ['And', 'HEAVENLYCREATURES.', "Jackson's"],
#   ['sorely', 'needs', 'something'],
#   True),
#  (6, 'LITTLE WOMEN', ['give', 'I', 'warmfeeling.'], ['a', 'high', '+1'], True),
#  (7,
#   'both senses',
#   ['homely---in', 'being', 'approaches'],
#   ['of', 'the', 'word--in'],
#   False),
#  (8,
#   'her imagination isseen',
#   ['Here', 'adult.', 'an'],
#   ['as', 'positive', 'and'],
#   False),
#  (9,
#   'is staying. Thereis',
#   ['she', 'where', 'house'],
#   ['sad', 'family', 'tragedy,'],
#   False)]

# %% [markdown]
# ### Feature Generation

# %%
def isitcapitalized(testcase):
    """Is the label capitalized? Return True or False"""
    return testcase[1].isupper()


def isthereayear(testcase):
    """Is the YEAR (YYYY) format in the surrounding 3 words before and after? Return True or False"""
    combo = testcase[2] + testcase[3]
    joined = "".join(combo)
    yearsearch = re.compile(r"\d\d\d\d")
    if re.search(yearsearch, joined):
        return True
    else:
        return False
    
def hasCueWords(testcase,cueword=None):
    """Are any of the cuewords we determined found in the surrounding text? Return True or False"""
    combo = testcase[2] + testcase[3]
    #combo = combo.split(' ')
    if cueword:
        for word in combo:
            if word == cueword:
                return True
    else:
        for word in combo:
            if word in cuewords:
                return True
    return False

def hasCueSymbols(testcase,cuesymbol=None):
    """Are any of the cuesymbols we determined found in the surrounding text? Return True or False"""
    combo = testcase[2] + testcase[3]
    #combo = combo.split(' ')
    if cuesymbol:
        for symb in combo:
            if symb == cuesymbol:
                return True
    else:
        for symb in cuesymbols:
            return True
    return False


def isPositive(testcase):
    """Is this a positive or negative example? Return True or False"""
    return testcase[-1]

def featureGen(cases):
    """This function brings together all of our feature generation functions and
    exports a pandas dataframe which can be fed into the ML classifiers"""
    #Set Key words and Key symbols
    cuewords = {'in':True, 'made':True, 'review':True, 'film':True, 'recommend':True, "showing":True, 
                'released':True, "The": True}
    cuesymbols = {'*':True, '(':True, ')':True ,'"':True, "'":True, ':':True, 'II':True, 'III':True}
    
    for cueword in cuewords:
        cuewords[cueword] = [hasCueWords(case, cueword) for case in cases]  
        
    for cuesymb in cuesymbols:
        cuesymbols[cuesymb] = [hasCueSymbols(case, cuesymb) for case in cases]   
        
    #Create subdataframes
    cuewords_df = pd.DataFrame(cuewords)
    cuesymbols_df = pd.DataFrame(cuesymbols)
    
    #Put it all together into master dataframe
    features = pd.DataFrame(
        {'hasYear':[isthereayear(case) for case in cases],
         'isCap':[isitcapitalized(case) for case in cases],
         'hasCueWords':[hasCueWords(case, cuewords) for case in cases],    
         'isPositive':[isPositive(case) for case in cases]
        }
    )
    df = pd.concat([cuewords_df, cuesymbols_df, features], axis=1)
    return(df)

# %%
df_set1 = featureGen(set1)
df_set1.head(n=10)
# Out:
#      The   film     in   made recommend released review showing      "      '  \
# 0  False   True  False  False     False    False   True   False  False  False
# 1  False  False   True  False     False    False  False   False  False  False
# 2  False  False  False  False     False    False  False   False  False  False
# 3   True  False  False  False     False    False  False   False  False  False
# 4  False  False  False  False     False    False  False   False  False  False
# 5  False  False  False  False     False    False  False   False  False  False
# 6  False  False  False  False     False    False  False   False  False  False
# 7  False  False  False  False     False    False  False   False  False  False
# 8  False  False  False  False     False    False  False   False  False  False
# 9  False  False  False  False     False    False  False   False  False  False
#
#        (      )      *      :     II    III hasCueWords hasYear  isCap  \
# 0  False  False  False  False  False  False       False   False   True
# 1  False  False  False  False  False  False       False    True   True
# 2  False  False  False  False  False  False       False   False   True
# 3  False  False  False  False  False  False       False   False   True
# 4  False  False  False  False  False  False       False   False   True
# 5  False  False  False  False  False  False       False   False   True
# 6  False  False  False  False  False  False       False   False   True
# 7  False  False  False  False  False  False       False   False  False
# 8  False  False  False  False  False  False       False   False  False
# 9  False  False  False  False  False  False       False   False  False
#
#   isPositive
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7      False
# 8      False
# 9      False

# %% [markdown]
# ## ML Models

# %%
def returnPrecision(y_truth, y_pred, classifier):
    """This function takes in an array of true observed and an array of predicted observed and outputs three 
    different measures for precision"""
    precision = {}
    precision["p_macro"] = precision_score(y_truth, y_pred, average='macro')
    precision["p_micro"] = precision_score(y_truth, y_pred, average='micro')
    precision["p_weight"] = precision_score(y_truth, y_pred, average='weighted')
    precision["p"] = precision_score(y_truth, y_pred, pos_label=True, average='binary')
    return pd.DataFrame(precision, index=[classifier])

def returnRecall(y_truth, y_pred, classifier):
    """This function takes in an array of true observed and an array of predicted observed and outputs three 
    different measures for precision"""
    recall = {}
    recall["r_macro"] = recall_score(y_truth, y_pred, average='macro')
    recall["r_micro"] = recall_score(y_truth, y_pred, average='micro')
    recall["r_weight"] = recall_score(y_truth, y_pred, average='weighted')
    recall["r"] = recall_score(y_truth, y_pred, pos_label=True, average="binary")
    return pd.DataFrame(recall, index=[classifier])

def returnF1(y_truth, y_pred, classifier):
    """This function takes in an array of true observed and an array of predicted observed and outputs three 
    different measures for F1"""
    F1 = {}
    F1["f1_macro"] = f1_score(y_truth, y_pred, average='macro')
    F1["f1_micro"] = f1_score(y_truth, y_pred, average='micro')
    F1["f1_weight"] = f1_score(y_truth, y_pred, average='weighted')
    F1["f1"] = f1_score(y_truth, y_pred, pos_label=True, average='binary')
    return pd.DataFrame(F1, index=[classifier])

def returnAccuracy(y_truth, y_pred, classifier):
    """This function takes in an array of true observed and an array of predicted observed and outputs accuracy"""
    accuracy = {}
    accuracy["accu"] = accuracy_score(y_truth, y_pred)
    return pd.DataFrame(accuracy, index=[classifier])

def returnMetrics(y_truth, y_pred, classifier):
    """Returns recall, precision, and accuracy as a pandas dataframe for each classifier"""
    rec = returnRecall(y_truth, y_pred, classifier)
    prec = returnPrecision(y_truth, y_pred, classifier)
    accu = returnAccuracy(y_truth, y_pred, classifier)
    f1 = returnF1(y_truth, y_pred, classifier)
    df = pd.concat([rec, prec, f1, accu], axis=1)
    return(df)

def runModels(X, y, kf, names, classifiers):
    """Function that runs over the classifiers and does k-fold cross-validation on the training set - returns metrics as dataframe"""
    df = pd.DataFrame([])
    for name, clf in zip(names, classifiers):
        for train_index, test_index in kf.split(X):
            clf.fit(X[train_index], y[train_index])
            predicted = clf.predict(X[test_index])
            data = returnMetrics(y[test_index], predicted, name)
            myscore = clf.score(X[test_index], y[test_index])
            score = pd.DataFrame({"score": myscore}, index = [name])
            ccat = pd.concat([data, score], axis = 1)
            df = df.append(ccat)
    return df

def runTruth(X, y, names, classifiers):
    """This function will run the ML classifiers on the testing set  - returns metrics as dataframe"""
    df = pd.DataFrame([])
    falses = []
    for name, clf in zip(names, classifiers):
        clf.fit(X, y)
        predicted = clf.predict(X)
        data = returnMetrics(y, predicted, name)
        df = df.append(data)
        for i in range(len(predicted)):
            if (predicted[i] != y[i]):
                outtuple = (i,predicted[i],y[i], name)
                falses.append(outtuple) 
    return (df, falses)
    

def MLmodels(X, Y, nsplits,crossv = True):
    """This function will run classifiers and export accuracy, precision, and recall for each classifier.
    N-fold cross validation has been automated here, where user determines number of folds"""
    ###########################################
    #Define classifiers
    ###########################################
    names = ["Decision Tree", "Logistic", "SVM", "Random Forest", "ExtraTrees"]
    classifiers = [ LogisticRegression(), tree.DecisionTreeClassifier(), svm.SVC(),
                   RandomForestClassifier(), ExtraTreesClassifier()]
    
    ###########################################
    #Create Train/Test Split
    ###########################################
    kf = KFold(n_splits = nsplits)
    
    ###########################################
    #Run Models
    ###########################################
    if(crossv == True): 
        return(runModels(X, y, kf, names, classifiers))
    else:
        return(runTruth(X, y, names, classifiers))

# %% [markdown]
# ### Prepare Set 1 and run ML models on Set 1

# %%
X = df_set1.ix[:, df_set1.columns != 'isPositive'].values
y = np.ravel(df_set1[['isPositive']].values)

# %% [markdown]
# Since this is our first set, we want to use k-fold cross validation. We choose to use 10 folds here:

# %%
crossv = True
nfolds = 10

if crossv == True:
    result = MLmodels(X, y, nfolds,crossv)
else:
    (result,idlist) = MLmodels(X, y, nfolds,crossv)

# %%
result
# Out:
#                  r   r_macro   r_micro  r_weight         p   p_macro  \
# Decision Tree  1.0  0.994444  0.994505  0.994505  0.989247  0.994624
# Decision Tree  1.0  0.994318  0.994505  0.994505  0.989474  0.994737
# Decision Tree  1.0  0.995098  0.994505  0.994505  0.987654  0.993827
# Decision Tree  1.0  0.987654  0.989011  0.989011  0.980583  0.990291
# Decision Tree  1.0  0.994382  0.994505  0.994505  0.989362  0.994681
# Decision Tree  1.0  1.000000  1.000000  1.000000  1.000000  1.000000
# Decision Tree  1.0  1.000000  1.000000  1.000000  1.000000  1.000000
# Decision Tree  1.0  1.000000  1.000000  1.000000  1.000000  1.000000
# Decision Tree  1.0  0.994048  0.994475  0.994475  0.989796  0.994898
# Decision Tree  1.0  0.996032  0.994475  0.994475  0.982143  0.991071
# Logistic       1.0  0.994444  0.994505  0.994505  0.989247  0.994624
# Logistic       1.0  0.994318  0.994505  0.994505  0.989474  0.994737
# Logistic       1.0  0.995098  0.994505  0.994505  0.987654  0.993827
# Logistic       1.0  0.987654  0.989011  0.989011  0.980583  0.990291
# Logistic       1.0  0.994382  0.994505  0.994505  0.989362  0.994681
# Logistic       1.0  1.000000  1.000000  1.000000  1.000000  1.000000
# Logistic       1.0  1.000000  1.000000  1.000000  1.000000  1.000000
# Logistic       1.0  1.000000  1.000000  1.000000  1.000000  1.000000
# Logistic       1.0  0.994048  0.994475  0.994475  0.989796  0.994898
# Logistic       1.0  0.996032  0.994475  0.994475  0.982143  0.991071
# SVM            1.0  0.994444  0.994505  0.994505  0.989247  0.994624
# SVM            1.0  0.994318  0.994505  0.994505  0.989474  0.994737
# SVM            1.0  0.995098  0.994505  0.994505  0.987654  0.993827
# SVM            1.0  0.987654  0.989011  0.989011  0.980583  0.990291
# SVM            1.0  0.994382  0.994505  0.994505  0.989362  0.994681
# SVM            1.0  1.000000  1.000000  1.000000  1.000000  1.000000
# SVM            1.0  1.000000  1.000000  1.000000  1.000000  1.000000
# SVM            1.0  1.000000  1.000000  1.000000  1.000000  1.000000
# SVM            1.0  0.994048  0.994475  0.994475  0.989796  0.994898
# SVM            1.0  0.996032  0.994475  0.994475  0.982143  0.991071
# Random Forest  1.0  0.994444  0.994505  0.994505  0.989247  0.994624
# Random Forest  1.0  0.994318  0.994505  0.994505  0.989474  0.994737
# Random Forest  1.0  0.995098  0.994505  0.994505  0.987654  0.993827
# Random Forest  1.0  0.987654  0.989011  0.989011  0.980583  0.990291
# Random Forest  1.0  0.994382  0.994505  0.994505  0.989362  0.994681
# Random Forest  1.0  1.000000  1.000000  1.000000  1.000000  1.000000
# Random Forest  1.0  1.000000  1.000000  1.000000  1.000000  1.000000
# Random Forest  1.0  1.000000  1.000000  1.000000  1.000000  1.000000
# Random Forest  1.0  0.994048  0.994475  0.994475  0.989796  0.994898
# Random Forest  1.0  0.996032  0.994475  0.994475  0.982143  0.991071
# ExtraTrees     1.0  0.994444  0.994505  0.994505  0.989247  0.994624
# ExtraTrees     1.0  0.994318  0.994505  0.994505  0.989474  0.994737
# ExtraTrees     1.0  0.995098  0.994505  0.994505  0.987654  0.993827
# ExtraTrees     1.0  0.987654  0.989011  0.989011  0.980583  0.990291
# ExtraTrees     1.0  0.994382  0.994505  0.994505  0.989362  0.994681
# ExtraTrees     1.0  1.000000  1.000000  1.000000  1.000000  1.000000
# ExtraTrees     1.0  1.000000  1.000000  1.000000  1.000000  1.000000
# ExtraTrees     1.0  1.000000  1.000000  1.000000  1.000000  1.000000
# ExtraTrees     1.0  0.994048  0.994475  0.994475  0.989796  0.994898
# ExtraTrees     1.0  0.996032  0.994475  0.994475  0.982143  0.991071
#
#                 p_micro  p_weight        f1  f1_macro  f1_micro  f1_weight  \
# Decision Tree  0.994505  0.994565  0.994595  0.994504  0.994505   0.994505
# Decision Tree  0.994505  0.994563  0.994709  0.994497  0.994505   0.994504
# Decision Tree  0.994505  0.994573  0.993789  0.994431  0.994505   0.994509
# Decision Tree  0.989011  0.989224  0.990196  0.988848  0.989011   0.988996
# Decision Tree  0.994505  0.994564  0.994652  0.994501  0.994505   0.994505
# Decision Tree  1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# Decision Tree  1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# Decision Tree  1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# Decision Tree  0.994475  0.994532  0.994872  0.994442  0.994475   0.994473
# Decision Tree  0.994475  0.994574  0.990991  0.993503  0.994475   0.994489
# Logistic       0.994505  0.994565  0.994595  0.994504  0.994505   0.994505
# Logistic       0.994505  0.994563  0.994709  0.994497  0.994505   0.994504
# Logistic       0.994505  0.994573  0.993789  0.994431  0.994505   0.994509
# Logistic       0.989011  0.989224  0.990196  0.988848  0.989011   0.988996
# Logistic       0.994505  0.994564  0.994652  0.994501  0.994505   0.994505
# Logistic       1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# Logistic       1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# Logistic       1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# Logistic       0.994475  0.994532  0.994872  0.994442  0.994475   0.994473
# Logistic       0.994475  0.994574  0.990991  0.993503  0.994475   0.994489
# SVM            0.994505  0.994565  0.994595  0.994504  0.994505   0.994505
# SVM            0.994505  0.994563  0.994709  0.994497  0.994505   0.994504
# SVM            0.994505  0.994573  0.993789  0.994431  0.994505   0.994509
# SVM            0.989011  0.989224  0.990196  0.988848  0.989011   0.988996
# SVM            0.994505  0.994564  0.994652  0.994501  0.994505   0.994505
# SVM            1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# SVM            1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# SVM            1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# SVM            0.994475  0.994532  0.994872  0.994442  0.994475   0.994473
# SVM            0.994475  0.994574  0.990991  0.993503  0.994475   0.994489
# Random Forest  0.994505  0.994565  0.994595  0.994504  0.994505   0.994505
# Random Forest  0.994505  0.994563  0.994709  0.994497  0.994505   0.994504
# Random Forest  0.994505  0.994573  0.993789  0.994431  0.994505   0.994509
# Random Forest  0.989011  0.989224  0.990196  0.988848  0.989011   0.988996
# Random Forest  0.994505  0.994564  0.994652  0.994501  0.994505   0.994505
# Random Forest  1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# Random Forest  1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# Random Forest  1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# Random Forest  0.994475  0.994532  0.994872  0.994442  0.994475   0.994473
# Random Forest  0.994475  0.994574  0.990991  0.993503  0.994475   0.994489
# ExtraTrees     0.994505  0.994565  0.994595  0.994504  0.994505   0.994505
# ExtraTrees     0.994505  0.994563  0.994709  0.994497  0.994505   0.994504
# ExtraTrees     0.994505  0.994573  0.993789  0.994431  0.994505   0.994509
# ExtraTrees     0.989011  0.989224  0.990196  0.988848  0.989011   0.988996
# ExtraTrees     0.994505  0.994564  0.994652  0.994501  0.994505   0.994505
# ExtraTrees     1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# ExtraTrees     1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# ExtraTrees     1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# ExtraTrees     0.994475  0.994532  0.994872  0.994442  0.994475   0.994473
# ExtraTrees     0.994475  0.994574  0.990991  0.993503  0.994475   0.994489
#
#                    accu     score
# Decision Tree  0.994505  0.994505
# Decision Tree  0.994505  0.994505
# Decision Tree  0.994505  0.994505
# Decision Tree  0.989011  0.989011
# Decision Tree  0.994505  0.994505
# Decision Tree  1.000000  1.000000
# Decision Tree  1.000000  1.000000
# Decision Tree  1.000000  1.000000
# Decision Tree  0.994475  0.994475
# Decision Tree  0.994475  0.994475
# Logistic       0.994505  0.994505
# Logistic       0.994505  0.994505
# Logistic       0.994505  0.994505
# Logistic       0.989011  0.989011
# Logistic       0.994505  0.994505
# Logistic       1.000000  1.000000
# Logistic       1.000000  1.000000
# Logistic       1.000000  1.000000
# Logistic       0.994475  0.994475
# Logistic       0.994475  0.994475
# SVM            0.994505  0.994505
# SVM            0.994505  0.994505
# SVM            0.994505  0.994505
# SVM            0.989011  0.989011
# SVM            0.994505  0.994505
# SVM            1.000000  1.000000
# SVM            1.000000  1.000000
# SVM            1.000000  1.000000
# SVM            0.994475  0.994475
# SVM            0.994475  0.994475
# Random Forest  0.994505  0.994505
# Random Forest  0.994505  0.994505
# Random Forest  0.994505  0.994505
# Random Forest  0.989011  0.989011
# Random Forest  0.994505  0.994505
# Random Forest  1.000000  1.000000
# Random Forest  1.000000  1.000000
# Random Forest  1.000000  1.000000
# Random Forest  0.994475  0.994475
# Random Forest  0.994475  0.994475
# ExtraTrees     0.994505  0.994505
# ExtraTrees     0.994505  0.994505
# ExtraTrees     0.994505  0.994505
# ExtraTrees     0.989011  0.989011
# ExtraTrees     0.994505  0.994505
# ExtraTrees     1.000000  1.000000
# ExtraTrees     1.000000  1.000000
# ExtraTrees     1.000000  1.000000
# ExtraTrees     0.994475  0.994475
# ExtraTrees     0.994475  0.994475

# %% [markdown]
# At this point, we are doing pretty well with respect to our precision/recall targets. We move on and test on set 2:

# %% [markdown]
# ### Prepare Set 2 and run ML models on Set 2

# %%
df_set2 = featureGen(set2)
df_set2.head(n=10)
# Out:
#      The   film     in   made recommend released review showing      "      '  \
# 0  False  False  False  False     False    False  False   False  False  False
# 1  False  False  False  False     False    False  False   False  False  False
# 2  False  False  False  False     False    False  False   False  False  False
# 3  False  False  False  False     False    False  False   False  False  False
# 4  False  False  False  False     False    False  False   False  False  False
# 5  False  False  False  False     False    False  False   False  False  False
# 6  False  False  False  False     False    False  False   False  False  False
# 7  False  False  False  False     False    False  False   False  False  False
# 8  False  False  False  False     False    False  False   False  False  False
# 9  False  False  False  False     False    False  False   False  False  False
#
#        (      )      *      :     II    III hasCueWords hasYear  isCap  \
# 0  False  False  False  False  False  False       False    True   True
# 1  False  False  False  False  False  False       False   False   True
# 2   True  False  False  False  False  False       False   False   True
# 3  False  False  False  False  False  False       False   False   True
# 4  False  False  False  False  False  False       False   False   True
# 5  False  False  False  False  False  False       False   False   True
# 6  False  False  False  False  False  False       False   False  False
# 7  False  False  False  False  False  False       False   False  False
# 8  False  False  False  False  False  False       False   False  False
# 9  False  False  False  False  False  False       False   False  False
#
#   isPositive
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False

# %%
X = df_set2.ix[:, df_set2.columns != 'isPositive'].values
y = np.ravel(df_set2[['isPositive']].values)

# %% [markdown]
# Here, we do not use CV and solely explore what our false positive/false negative misclassifications are:

# %%
crossv = False
nfolds = 10

if crossv == True:
    result = MLmodels(X, y, nfolds, crossv)
else:
    (result,idlist) = MLmodels(X, y, nfolds,crossv)

# %%
result
# Out:
#                       r   r_macro   r_micro  r_weight         p   p_macro  \
# Decision Tree  0.807281  0.886581  0.909643  0.909643  0.928571  0.914889
# Logistic       0.860814  0.903936  0.916477  0.916477  0.899329  0.912308
# SVM            0.773019  0.871216  0.899772  0.899772  0.932817  0.909419
# Random Forest  0.862955  0.904419  0.916477  0.916477  0.897550  0.911909
# ExtraTrees     0.860814  0.903936  0.916477  0.916477  0.899329  0.912308
#
#                 p_micro  p_weight        f1  f1_macro  f1_micro  f1_weight  \
# Decision Tree  0.909643  0.910911  0.863688  0.898057  0.909643   0.908051
# Logistic       0.916477  0.916083  0.879650  0.907848  0.916477   0.916049
# SVM            0.899772  0.902615  0.845433  0.885638  0.899772   0.897330
# Random Forest  0.916477  0.916084  0.879913  0.907942  0.916477   0.916094
# ExtraTrees     0.916477  0.916083  0.879650  0.907848  0.916477   0.916049
#
#                    accu
# Decision Tree  0.909643
# Logistic       0.916477
# SVM            0.899772
# Random Forest  0.916477
# ExtraTrees     0.916477

# %% [markdown]
# It looks like both our precision and recall fell a little bit. Let us explore our misclassified labels.

# %%
for i in idlist:
    print(set2[i[0]], i[1], i[2], i[3])
# Out:
# (20, '"Alien"', ['the', 'of', 'any'], ['films.Weaver,', 'perhaps', 'inspired'], True) False True Decision Tree
# (107, "'s MUCH ADO ABOUT NOTHING", ['KennethBranagh', 'in', 'onscreen'], ['.', 'But', 'if'], True) False True Decision Tree
# (123, 'ANNA KARENINAA film review', ['', '', ''], ['by', 'James', 'BerardinelliCopyright'], True) False True Decision Tree
# (125, "'s (IMMORTAL BELOVED)", ['Rose', ',Bernard', 'KARENINA'], ['attempt', 'to', 'bring'], True) False True Decision Tree
# (135, "'s HAMLET", ['Branagh', 'Kenneth', 'since'], ['.', 'Ballroominteriors,', 'landscapes,'], True) False True Decision Tree
# (140, 'TO 10):', ['(0', 'BerardinelliRATING', 'James'], ['5.5Alternative', 'Scale:', '**'], False) True False Decision Tree
# (166, 'I', ['though', '--', 'Gertrude'], ['must', "confessI'm", 'still'], False) True False Decision Tree
# (181, '"Amadeus"', ['glance,', 'first', 'Forman.At'], ['seems', 'like', 'a'], True) False True Decision Tree
# (182, '"Amadeus."', ['of', 'view', 'my'], ['After', 'Emperor', 'Joseph'], True) False True Decision Tree
# (183, '"One Flew Over The Cuckoo\'sNest," "ThePeople Vs. Larry Flynt"', ['Forman:', 'by', '[also'], [']visit', "Chad'z", 'Movie'], True) False True Decision Tree
# (222, 'Honeymooners ,"', ['The', '"', 'movies,'], ['all', 'those', 'big'], False) True False Decision Tree
# (234, '"', ['Batman', '"', 'Batman.Still,'], ["isn't", 'bad', 'at'], False) True False Decision Tree
# (249, 'Dances With Wolves', ['become', 'to', 'experiences'], ['?please', 'visit', "Chad'z"], True) False True Decision Tree
# (274, 'Batman', ['Dowling', 'Chuck', '1997'], ['(1989)', '***', 'out'], True) False True Decision Tree
# (278, 'I', ['oscar.', 'an', 'won'], ['could', 'just', 'imagine'], False) True False Decision Tree
# (296, 'I', ['movie.', 'this', 'about'], ['have', 'thesinking', 'feeling'], False) True False Decision Tree
# (304, 'Annie Hall', ['of"', 'exception', 'the'], [',"', 'no', 'other'], True) False True Decision Tree
# (321, 'of"', ['version', 'his', 'is'], ['1984', '"', 'or'], False) True False Decision Tree
# (355, 'Midnight Cowboy "', ['"', 'symbolicof', 'is'], ['-', 'there', 'is'], False) True False Decision Tree
# (438, "that there's no", ['itclear', 'made', 'I'], ['difference', 'between', '"'], False) True False Decision Tree
# (441, 'Hellraiser " or', ['"', 'thananother', 'better'], ['"', 'Halloween', '"'], False) True False Decision Tree
# (444, '2001: A Space Odyssey', ['', '', ''], ["Chad'z", 'rating:', '****'], True) False True Decision Tree
# (449, 'makes', ['answer.What', 'correct', 'one'], ['"', '2001:', 'A'], False) True False Decision Tree
# (457, 'Scream', ['', '', ''], ["Chad'z", 'rating:', '***'], True) False True Decision Tree
# (496, "that, '", ['importantthan', 'more', 'but'], ['Platoon', "'", 'forced'], False) True False Decision Tree
# (497, 'Total Recall', ['', '', ''], ['A', 'Film', 'Review'], True) False True Decision Tree
# (503, 'Speed 2', ['Ex.', 'enjoyable.', 'of'], [',', "TheDevil's", 'Own'], True) False True Decision Tree
# (504, "TheDevil's Own", [',', '2', 'Speed'], ['*', '=', 'Poor'], True) False True Decision Tree
# (505, 'Congo', ['Ex.', 'picture.', 'unbearable'], [',', 'Batmanand', 'Robin'], True) False True Decision Tree
# (506, 'Batmanand Robin', [',', 'Congo', 'Ex.'], ['Copyright', '1997', 'Jesse'], True) False True Decision Tree
# (530, 'Raiders of the Lost Ark', ['Spielberg', 'Steven', 'by:'], ['(1981)', 'is', 'the'], True) False True Decision Tree
# (544, 'Congo', [',', 'Robin', 'and'], [')Copyright', '1997', 'Jesse'], True) False True Decision Tree
# (555, 'Scream', ['', '', ''], ['(1997)Starring', 'Neve', 'Campbell,'], True) False True Decision Tree
# (556, 'Scream: The Sequel', ['for', 'waiting', "I'mjust"], ['.', '', ''], True) False True Decision Tree
# (602, "DeerHunter '. '", ['The', "'", 'to'], ['True', 'Grit', "'"], False) True False Decision Tree
# (643, '2001:Space Odyssey', ['recommend', 'I', 'pacing.'], ['because', 'it', 'is'], True) False True Decision Tree
# (655, 'Nightmare on Elm Street', ['knownis', 'most', 'his'], ['.', 'In', 'Scream'], True) False True Decision Tree
# (656, 'Scream', ['In', '.', 'Street'], ['Craven', 'knows', 'that'], True) False True Decision Tree
# (657, 'Scream', ['in', 'effort', 'good'], ['.', 'It', 'was'], True) False True Decision Tree
# (658, 'Scream', ['miss', "Don't", 'film.'], ['.', 'And', 'as'], True) False True Decision Tree
# (669, 'Legend', ['', '', ''], ['(1985)A', 'movie', 'review'], True) False True Decision Tree
# (683, 'Scream', ['mean"', 'this', 'Does'], ['"\'s', 'plot', 'will'], True) False True Decision Tree
# (697, 'Jaws', ['whilemaking', 'learned', 'he'], ['-', 'our', 'imagination'], True) False True Decision Tree
# (710, 'original trailer for', ['the', 'In', '('], ['Psychothere', 'is', 'a'], False) True False Decision Tree
# (712, 'Raiders Of The LostArk', ['athttp://www.gafieldlib.com/yanews/july97/max/max.html', 'reviews', "Max's"], ['could', 'be', 'called'], True) False True Decision Tree
# (726, 'Patriot Games', ['', '', ''], ['(1992)Grade:', '44"', 'Patriot'], True) False True Decision Tree
# (734, 'tries', ['"', 'PatriotGames', 'lately?""'], ['to', 'create', 'tension'], False) True False Decision Tree
# (751, 'Patton', ['', '', ''], ['(1970)Grade:', '89"', 'Patton'], True) False True Decision Tree
# (763, 'Julia', ['', '', ''], ['(1977)Grade:', '78"', 'Julia'], True) False True Decision Tree
# (775, '"', ['her.Still,', 'to', 'figure'], ['Julia', '"', 'is'], False) True False Decision Tree
# (777, 'Romeo And Juliet', ["Luhrman's", 'andBaz', 'brilliant,'], ['colorful', 'and', 'deeply'], True) False True Decision Tree
# (778, 'Sense AndSensibility', ['herself...(see', 'Thompson', 'Emma'], [')Vincent', 'Merlaud', ''], True) False True Decision Tree
# (789, 'Rebecca', ['', '', ''], ['(1940)Grade:', '97', 'Quiz'], True) False True Decision Tree
# (798, 'in the', ['also', 'is', '"'], ['running.', 'Other', 'films'], False) True False Decision Tree
# (807, 'Alien', ['', '', ''], ["Chad'z", 'rating:', '**1/2'], True) False True Decision Tree
# (809, '2001', ['in"', 'used', 'technique'], ['")', 'to', 'investigate'], True) False True Decision Tree
# (821, 'Eraserhead', ['', '', ''], ['*', '*', '*'], True) False True Decision Tree
# (839, 'Eraserhead "', ['"', 'life.', 'anunpleasant'], ['could', 'probably', 'be'], False) True False Decision Tree
# (841, 'and directed', ['1976Written', '1/2R,', '*'], ['by', 'David', 'Lynch.Starring'], False) True False Decision Tree
# (843, 'Time Bandits', ['Patterson', 'Kevin', 'by'], ['*', '*', '*PG,'], True) False True Decision Tree
# (860, 'succeeds at', ['"', 'Bandits', 'Time'], ['both', 'romanticizing', 'and'], False) True False Decision Tree
# (885, 'Scream', ['of"', 'downside', 'the'], [',"', 'which', 'is'], True) False True Decision Tree
# (903, 'with', ['opens', '"', 'Scream'], ['one', 'of', 'the'], False) True False Decision Tree
# (905, 'Aliens', ['', '', ''], ["Chad'z", 'rating:', '**'], True) False True Decision Tree
# (924, 'which', ['To', '"', '.'], ['I', 'say,', '"THE'], False) True False Decision Tree
# (927, 'which I', ['To', '"', '.'], ['say,', '"THE', 'greatest'], False) True False Decision Tree
# (930, 'Days of Heaven', ['', '', ''], ['(1978)Grade:', '93The', 'documentary'], True) False True Decision Tree
# (937, '"lavished more screen', ['Cinematography', 'of', 'Art'], ['time', 'on', '"'], False) True False Decision Tree
# (942, 'to be." Days', ['appear', 'they', 'as'], ['ofHeaven', '"', 'was'], False) True False Decision Tree
# (947, 'Alien: Resurrection', ['', '', ''], ['(Aliens', '4)', 'Directed'], True) False True Decision Tree
# (948, '_Aliens_', ['stylefor', 'different', 'another'], ['.', 'The', 'fact'], True) False True Decision Tree
# (949, '_Alien_', ['an', 'see', 'to'], ['film,', 'this', 'is'], True) False True Decision Tree
# (960, 'Aliens', ['', '', ''], ['(1986)Review', 'by', 'Laurence'], True) False True Decision Tree
# (961, 'Citizen Kane', ['was', 'it', 'dramas,'], [',', 'with', 'arthouse'], True) False True Decision Tree
# (962, 'Forrest Gump', ['did', 'as', 'event,'], ['four', 'yearsago.With', 'action'], True) False True Decision Tree
# (963, 'Alien', ['parent,', 'equally-innovative', "it's"], ['(1979).', 'Directed', 'andwritten'], True) False True Decision Tree
# (964, 'The Terminator', ['sci-fithriller', 'his', 'to'], ['(1984).While', 'the', 'original'], True) False True Decision Tree
# (965, 'T2: Judgement Day', ['film,', 'Cameron', 'another'], [',', 'in', '1991.'], True) False True Decision Tree
# (977, 'Hercules', ['(especially', 'releases...', 'Disney'], [')...', 'emotion.All', 'the'], True) False True Decision Tree
# (978, 'Beauty & the Beast', ["sinceDisney's", 'Not', 'together.'], ['has', 'there', 'been'], True) False True Decision Tree
# (990, 'Alien: Resurrection', ['', '', ''], ["won't", 'revive', 'creatively'], True) False True Decision Tree
# (994, 'Alien:Resurrection', ['mess,"', 'latest', 'this'], [',"', 'slithering', 'into'], True) False True Decision Tree
# (997, 'The Poiseidon Adventure', ['from"', 'directly', 'quoted'], ['"--but', 'without', 'the'], True) False True Decision Tree
# (1018, 'Seven', ['Fincher(`', 'David', 'like'], ["')'s", 'part', 'three,'], True) False True Decision Tree
# (1019, 'Aliens', ['`', "JamesCameron's", 'in'], ["'.", 'But', 'I'], True) False True Decision Tree
# (1020, 'Independence Day', ['`', 'in', 'hear'], ["'.", "They're", 'uniqueducks'], True) False True Decision Tree
# (1022, 'aesthetically', ['artfullymade,', 'is', "'"], ['pretty', 'like', 'David'], False) True False Decision Tree
# (1032, 'Anastasia', ['', '', ''], ['a', 'reviewBy', 'Jeremiah'], True) False True Decision Tree
# (1033, 'Anastasia', ['showingof', 'late', 'the'], ['at', 'one', 'of'], True) False True Decision Tree
# (1034, 'Anastasia', ['digress.', 'I', 'but'], ['is', 'the', 'first'], True) False True Decision Tree
# (1035, 'The Secret of Nimh', ['entertainment,including', 'animated', 'of'], [',', 'An', 'American'], True) False True Decision Tree
# (1036, 'An American Tail', [',', 'Nimh', 'of'], [',', 'and', 'All'], True) False True Decision Tree
# (1037, 'All Dogs Go To Heaven', ['and', ',', 'Tail'], [',just', 'to', 'name'], True) False True Decision Tree
# (1040, 'The Black Cauldron', ['of', 'reminded', 'was'], ['a', 'bit,where', 'armies'], True) False True Decision Tree
# (1041, 'Anastaisa', ['if', 'besurprised', 'would'], ['grosses', 'in', 'the'], True) False True Decision Tree
# (1042, 'Alladin', ['in', 'parrot', 'The'], ['as', 'played', 'by'], True) False True Decision Tree
# (1068, 'Alien: Resurrection', ['', '', ''], ['(1997)Sigourney', 'Weaver,', 'Winona'], True) False True Decision Tree
# (1073, 'Resurrection', ['alliance."', 'uneasy', 'an'], ['\x12s"', 'action', 'sequences'], True) False True Decision Tree
# (1097, '60% of ANASTASIA', ["You'llsee", '.', 'CANDLESHOE'], ['there.Dave', 'ThompsenEmail', ':'], False) True False Decision Tree
# (1135, 'Alien', ['', '', ''], ['(1979)Rated', 'R', 'for'], True) False True Decision Tree
# (1163, 'Aliens', ['', '', ''], ['(1986)Rated', 'R', 'for'], True) False True Decision Tree
# (1174, 'Blade Runner', ['when', 'was', 'outmid-day'], ['was', 'released.', 'Today'], True) False True Decision Tree
# (1175, 'Alien Resurrection', ['-', 'further', 'any'], ['is', '_great_.', 'Webbies'], True) False True Decision Tree
# (1176, 'English Patient', ['the', "Itisn't", 'rating.'], ['(but', 'maybe', 'there'], True) False True Decision Tree
# (1177, 'Bride of Dracula', ['the', 'with', 'inlove'], ['(I', 'still', 'fall'], True) False True Decision Tree
# (1178, 'Alien Resurrection', ['love', 'yagotta', 'then'], ['.', 'It', 'has'], True) False True Decision Tree
# (1179, 'Zorro', ['for', 'was', 'lot'], ['.', 'Yes,', 'Zorro'], True) False True Decision Tree
# (1180, 'Zorro', ['Yes,', '.', 'Zorro'], ['.', 'I', 'kept'], True) False True Decision Tree
# (1191, 'Alien Resurrection', ['', '', ''], ['Director:', 'Jean-Pierre', 'JeunetStarring:'], True) False True Decision Tree
# (1192, 'Alien 3', ['in', 'died', 'she'], ['.', 'But', 'those'], True) False True Decision Tree
# (1193, 'AlienResurrection', ['that', 'thing', 'stuff.Another'], ['offers', 'that', 'the'], True) False True Decision Tree
# (1194, 'Alien 3', ['After', 'now?', 'series'], [',', 'we', 'were'], True) False True Decision Tree
# (1205, 'Anastasia', ['', '', ''], ['Directors:', 'Don', 'Bluth'], True) False True Decision Tree
# (1208, 'French Kiss', ['in', 'character', 'her'], [')', 'and', 'plenty'], True) False True Decision Tree
# (1215, 'front ofimpressionist backgrounds)Somehow,', ['in', 'dance', 'to'], ['the', '"', 'Magic'], False) True False Decision Tree
# (1219, 'Alien Resurrection', ['', '', ''], ['(1997)Rated', 'R', 'for'], True) False True Decision Tree
# (1230, 'Anastasia', ['', '', ''], ['(1997)Rating:', '3.0', 'stars'], True) False True Decision Tree
# (1241, 'Alien', ['', '', ''], ['(1979)A', 'movie', 'review'], True) False True Decision Tree
# (1272, 'LOST CHILDREN .', ['OF', 'CITY', 'masterpiece'], ['His', 'strengths', 'are'], False) True False Decision Tree
# (20, '"Alien"', ['the', 'of', 'any'], ['films.Weaver,', 'perhaps', 'inspired'], True) False True Logistic
# (40, '*', ['*', 'Kelsey*', 'Benjamin'], ['*', '(out', 'of'], False) True False Logistic
# (107, "'s MUCH ADO ABOUT NOTHING", ['KennethBranagh', 'in', 'onscreen'], ['.', 'But', 'if'], True) False True Logistic
# (123, 'ANNA KARENINAA film review', ['', '', ''], ['by', 'James', 'BerardinelliCopyright'], True) False True Logistic
# (125, "'s (IMMORTAL BELOVED)", ['Rose', ',Bernard', 'KARENINA'], ['attempt', 'to', 'bring'], True) False True Logistic
# (135, "'s HAMLET", ['Branagh', 'Kenneth', 'since'], ['.', 'Ballroominteriors,', 'landscapes,'], True) False True Logistic
# (140, 'TO 10):', ['(0', 'BerardinelliRATING', 'James'], ['5.5Alternative', 'Scale:', '**'], False) True False Logistic
# (166, 'I', ['though', '--', 'Gertrude'], ['must', "confessI'm", 'still'], False) True False Logistic
# (181, '"Amadeus"', ['glance,', 'first', 'Forman.At'], ['seems', 'like', 'a'], True) False True Logistic
# (182, '"Amadeus."', ['of', 'view', 'my'], ['After', 'Emperor', 'Joseph'], True) False True Logistic
# (183, '"One Flew Over The Cuckoo\'sNest," "ThePeople Vs. Larry Flynt"', ['Forman:', 'by', '[also'], [']visit', "Chad'z", 'Movie'], True) False True Logistic
# (209, 'and Cooper RedwineCopyright', ['Ivana', 'by', 'review'], ['1997', 'Ivana', 'and'], False) True False Logistic
# (222, 'Honeymooners ,"', ['The', '"', 'movies,'], ['all', 'those', 'big'], False) True False Logistic
# (234, '"', ['Batman', '"', 'Batman.Still,'], ["isn't", 'bad', 'at'], False) True False Logistic
# (249, 'Dances With Wolves', ['become', 'to', 'experiences'], ['?please', 'visit', "Chad'z"], True) False True Logistic
# (259, 'Chad Polenz***1/2', ['1997', 'PolenzCopyright', 'Chad'], ['(out', 'of', '4'], False) True False Logistic
# (278, 'I', ['oscar.', 'an', 'won'], ['could', 'just', 'imagine'], False) True False Logistic
# (296, 'I', ['movie.', 'this', 'about'], ['have', 'thesinking', 'feeling'], False) True False Logistic
# (304, 'Annie Hall', ['of"', 'exception', 'the'], [',"', 'no', 'other'], True) False True Logistic
# (321, 'of"', ['version', 'his', 'is'], ['1984', '"', 'or'], False) True False Logistic
# (337, 'Polenz**** (out', ['Chad', '1997', 'PolenzCopyright'], ['of', '4', '='], False) True False Logistic
# (355, 'Midnight Cowboy "', ['"', 'symbolicof', 'is'], ['-', 'there', 'is'], False) True False Logistic
# (441, 'Hellraiser " or', ['"', 'thananother', 'better'], ['"', 'Halloween', '"'], False) True False Logistic
# (444, '2001: A Space Odyssey', ['', '', ''], ["Chad'z", 'rating:', '****'], True) False True Logistic
# (449, 'makes', ['answer.What', 'correct', 'one'], ['"', '2001:', 'A'], False) True False Logistic
# (457, 'Scream', ['', '', ''], ["Chad'z", 'rating:', '***'], True) False True Logistic
# (496, "that, '", ['importantthan', 'more', 'but'], ['Platoon', "'", 'forced'], False) True False Logistic
# (497, 'Total Recall', ['', '', ''], ['A', 'Film', 'Review'], True) False True Logistic
# (503, 'Speed 2', ['Ex.', 'enjoyable.', 'of'], [',', "TheDevil's", 'Own'], True) False True Logistic
# (505, 'Congo', ['Ex.', 'picture.', 'unbearable'], [',', 'Batmanand', 'Robin'], True) False True Logistic
# (556, 'Scream: The Sequel', ['for', 'waiting', "I'mjust"], ['.', '', ''], True) False True Logistic
# (645, 'was', ['what', 'reflects', '2001'], ['current', 'then,', 'and'], False) True False Logistic
# (655, 'Nightmare on Elm Street', ['knownis', 'most', 'his'], ['.', 'In', 'Scream'], True) False True Logistic
# (656, 'Scream', ['In', '.', 'Street'], ['Craven', 'knows', 'that'], True) False True Logistic
# (657, 'Scream', ['in', 'effort', 'good'], ['.', 'It', 'was'], True) False True Logistic
# (658, 'Scream', ['miss', "Don't", 'film.'], ['.', 'And', 'as'], True) False True Logistic
# (676, 'Yegulalp[NB: This review', ['Serdar', 'by', '1997'], ['is', 'designed', 'to'], False) True False Logistic
# (683, 'Scream', ['mean"', 'this', 'Does'], ['"\'s', 'plot', 'will'], True) False True Logistic
# (697, 'Jaws', ['whilemaking', 'learned', 'he'], ['-', 'our', 'imagination'], True) False True Logistic
# (710, 'original trailer for', ['the', 'In', '('], ['Psychothere', 'is', 'a'], False) True False Logistic
# (712, 'Raiders Of The LostArk', ['athttp://www.gafieldlib.com/yanews/july97/max/max.html', 'reviews', "Max's"], ['could', 'be', 'called'], True) False True Logistic
# (734, 'tries', ['"', 'PatriotGames', 'lately?""'], ['to', 'create', 'tension'], False) True False Logistic
# (775, '"', ['her.Still,', 'to', 'figure'], ['Julia', '"', 'is'], False) True False Logistic
# (777, 'Romeo And Juliet', ["Luhrman's", 'andBaz', 'brilliant,'], ['colorful', 'and', 'deeply'], True) False True Logistic
# (778, 'Sense AndSensibility', ['herself...(see', 'Thompson', 'Emma'], [')Vincent', 'Merlaud', ''], True) False True Logistic
# (798, 'in the', ['also', 'is', '"'], ['running.', 'Other', 'films'], False) True False Logistic
# (807, 'Alien', ['', '', ''], ["Chad'z", 'rating:', '**1/2'], True) False True Logistic
# (809, '2001', ['in"', 'used', 'technique'], ['")', 'to', 'investigate'], True) False True Logistic
# (839, 'Eraserhead "', ['"', 'life.', 'anunpleasant'], ['could', 'probably', 'be'], False) True False Logistic
# (857, '1981Directed by', ['*PG,', '*', '*'], ['Terry', 'Gilliam.', 'Written'], False) True False Logistic
# (860, 'succeeds at', ['"', 'Bandits', 'Time'], ['both', 'romanticizing', 'and'], False) True False Logistic
# (885, 'Scream', ['of"', 'downside', 'the'], [',"', 'which', 'is'], True) False True Logistic
# (903, 'with', ['opens', '"', 'Scream'], ['one', 'of', 'the'], False) True False Logistic
# (905, 'Aliens', ['', '', ''], ["Chad'z", 'rating:', '**'], True) False True Logistic
# (924, 'which', ['To', '"', '.'], ['I', 'say,', '"THE'], False) True False Logistic
# (927, 'which I', ['To', '"', '.'], ['say,', '"THE', 'greatest'], False) True False Logistic
# (937, '"lavished more screen', ['Cinematography', 'of', 'Art'], ['time', 'on', '"'], False) True False Logistic
# (942, 'to be." Days', ['appear', 'they', 'as'], ['ofHeaven', '"', 'was'], False) True False Logistic
# (947, 'Alien: Resurrection', ['', '', ''], ['(Aliens', '4)', 'Directed'], True) False True Logistic
# (948, '_Aliens_', ['stylefor', 'different', 'another'], ['.', 'The', 'fact'], True) False True Logistic
# (949, '_Alien_', ['an', 'see', 'to'], ['film,', 'this', 'is'], True) False True Logistic
# (961, 'Citizen Kane', ['was', 'it', 'dramas,'], [',', 'with', 'arthouse'], True) False True Logistic
# (962, 'Forrest Gump', ['did', 'as', 'event,'], ['four', 'yearsago.With', 'action'], True) False True Logistic
# (965, 'T2: Judgement Day', ['film,', 'Cameron', 'another'], [',', 'in', '1991.'], True) False True Logistic
# (973, 'Directed', ['(1979).', 'Alien', 'parent,'], ['andwritten', 'by', 'James'], False) True False Logistic
# (977, 'Hercules', ['(especially', 'releases...', 'Disney'], [')...', 'emotion.All', 'the'], True) False True Logistic
# (978, 'Beauty & the Beast', ["sinceDisney's", 'Not', 'together.'], ['has', 'there', 'been'], True) False True Logistic
# (990, 'Alien: Resurrection', ['', '', ''], ["won't", 'revive', 'creatively'], True) False True Logistic
# (994, 'Alien:Resurrection', ['mess,"', 'latest', 'this'], [',"', 'slithering', 'into'], True) False True Logistic
# (997, 'The Poiseidon Adventure', ['from"', 'directly', 'quoted'], ['"--but', 'without', 'the'], True) False True Logistic
# (1018, 'Seven', ['Fincher(`', 'David', 'like'], ["')'s", 'part', 'three,'], True) False True Logistic
# (1019, 'Aliens', ['`', "JamesCameron's", 'in'], ["'.", 'But', 'I'], True) False True Logistic
# (1020, 'Independence Day', ['`', 'in', 'hear'], ["'.", "They're", 'uniqueducks'], True) False True Logistic
# (1022, 'aesthetically', ['artfullymade,', 'is', "'"], ['pretty', 'like', 'David'], False) True False Logistic
# (1032, 'Anastasia', ['', '', ''], ['a', 'reviewBy', 'Jeremiah'], True) False True Logistic
# (1033, 'Anastasia', ['showingof', 'late', 'the'], ['at', 'one', 'of'], True) False True Logistic
# (1034, 'Anastasia', ['digress.', 'I', 'but'], ['is', 'the', 'first'], True) False True Logistic
# (1035, 'The Secret of Nimh', ['entertainment,including', 'animated', 'of'], [',', 'An', 'American'], True) False True Logistic
# (1036, 'An American Tail', [',', 'Nimh', 'of'], [',', 'and', 'All'], True) False True Logistic
# (1037, 'All Dogs Go To Heaven', ['and', ',', 'Tail'], [',just', 'to', 'name'], True) False True Logistic
# (1040, 'The Black Cauldron', ['of', 'reminded', 'was'], ['a', 'bit,where', 'armies'], True) False True Logistic
# (1041, 'Anastaisa', ['if', 'besurprised', 'would'], ['grosses', 'in', 'the'], True) False True Logistic
# (1042, 'Alladin', ['in', 'parrot', 'The'], ['as', 'played', 'by'], True) False True Logistic
# (1073, 'Resurrection', ['alliance."', 'uneasy', 'an'], ['\x12s"', 'action', 'sequences'], True) False True Logistic
# (1097, '60% of ANASTASIA', ["You'llsee", '.', 'CANDLESHOE'], ['there.Dave', 'ThompsenEmail', ':'], False) True False Logistic
# (1174, 'Blade Runner', ['when', 'was', 'outmid-day'], ['was', 'released.', 'Today'], True) False True Logistic
# (1175, 'Alien Resurrection', ['-', 'further', 'any'], ['is', '_great_.', 'Webbies'], True) False True Logistic
# (1176, 'English Patient', ['the', "Itisn't", 'rating.'], ['(but', 'maybe', 'there'], True) False True Logistic
# (1177, 'Bride of Dracula', ['the', 'with', 'inlove'], ['(I', 'still', 'fall'], True) False True Logistic
# (1178, 'Alien Resurrection', ['love', 'yagotta', 'then'], ['.', 'It', 'has'], True) False True Logistic
# (1179, 'Zorro', ['for', 'was', 'lot'], ['.', 'Yes,', 'Zorro'], True) False True Logistic
# (1180, 'Zorro', ['Yes,', '.', 'Zorro'], ['.', 'I', 'kept'], True) False True Logistic
# (1191, 'Alien Resurrection', ['', '', ''], ['Director:', 'Jean-Pierre', 'JeunetStarring:'], True) False True Logistic
# (1192, 'Alien 3', ['in', 'died', 'she'], ['.', 'But', 'those'], True) False True Logistic
# (1193, 'AlienResurrection', ['that', 'thing', 'stuff.Another'], ['offers', 'that', 'the'], True) False True Logistic
# (1194, 'Alien 3', ['After', 'now?', 'series'], [',', 'we', 'were'], True) False True Logistic
# (1205, 'Anastasia', ['', '', ''], ['Directors:', 'Don', 'Bluth'], True) False True Logistic
# (1215, 'front ofimpressionist backgrounds)Somehow,', ['in', 'dance', 'to'], ['the', '"', 'Magic'], False) True False Logistic
# (1272, 'LOST CHILDREN .', ['OF', 'CITY', 'masterpiece'], ['His', 'strengths', 'are'], False) True False Logistic
# (1298, 'second film, is', ['the', '(1986),', 'ALIENS'], ['a', 'classicas', 'well.'], False) True False Logistic
# (1307, 'Maria', ['1', '9917.html-rwx------', '18:43'], ['None', '4465', 'Feb'], False) True False Logistic
# (1308, '17 18:43', ['Feb', '4690', 'None'], ['9729.html-rwx------', '1', 'Maria'], False) True False Logistic
# (1309, 'None 5915', ['Maria', '1', '9646.html-rwx------'], ['Feb', '17', '18:43'], False) True False Logistic
# (1310, 'Maria None 4127', ['1', '8669.html-rwx------', '18:43'], ['Feb', '17', '18:43'], False) True False Logistic
# (1311, '1', ['8005.html-rwx------', '18:43', '17'], ['Maria', 'None', '3234'], False) True False Logistic
# (1312, '9494.html-rwx------', ['18:43', '17', 'Feb'], ['1', 'Maria', 'None'], False) True False Logistic
# (1313, 'Feb 17', ['588', 'None', 'Maria'], ['18:43', '9915.html-rwx------', '1'], False) True False Logistic
# (1314, 'None', ['Maria', '1', '9180.html-rwx------'], ['1695', 'Feb', '17'], False) True False Logistic
# (1315, 'Feb', ['4042', 'None', 'Maria'], ['17', '18:43', '8157.html-rwx------'], False) True False Logistic
# (1316, 'Maria', ['1', '9917.html-rwx------', '18:43'], ['None', '4465', 'Feb'], False) True False Logistic
# (20, '"Alien"', ['the', 'of', 'any'], ['films.Weaver,', 'perhaps', 'inspired'], True) False True SVM
# (107, "'s MUCH ADO ABOUT NOTHING", ['KennethBranagh', 'in', 'onscreen'], ['.', 'But', 'if'], True) False True SVM
# (123, 'ANNA KARENINAA film review', ['', '', ''], ['by', 'James', 'BerardinelliCopyright'], True) False True SVM
# (125, "'s (IMMORTAL BELOVED)", ['Rose', ',Bernard', 'KARENINA'], ['attempt', 'to', 'bring'], True) False True SVM
# (130, "BRAVEHEART)/myy>) is a cool, regal beauty -- not the right type atall to play the hot-blooded, passionate Anna. Marceau is a goodactress, but she's wrong for this role, and her icy rendering of Annaleaves viewers largely unconcerned about the fate of the character.Likewise, Mia Kirshner ( EXOTICA", ['(', 'SophieMarceau', 'actress'], [')', 'as', 'Kitty'], True) False True SVM
# (135, "'s HAMLET", ['Branagh', 'Kenneth', 'since'], ['.', 'Ballroominteriors,', 'landscapes,'], True) False True SVM
# (140, 'TO 10):', ['(0', 'BerardinelliRATING', 'James'], ['5.5Alternative', 'Scale:', '**'], False) True False SVM
# (166, 'I', ['though', '--', 'Gertrude'], ['must', "confessI'm", 'still'], False) True False SVM
# (181, '"Amadeus"', ['glance,', 'first', 'Forman.At'], ['seems', 'like', 'a'], True) False True SVM
# (182, '"Amadeus."', ['of', 'view', 'my'], ['After', 'Emperor', 'Joseph'], True) False True SVM
# (183, '"One Flew Over The Cuckoo\'sNest," "ThePeople Vs. Larry Flynt"', ['Forman:', 'by', '[also'], [']visit', "Chad'z", 'Movie'], True) False True SVM
# (222, 'Honeymooners ,"', ['The', '"', 'movies,'], ['all', 'those', 'big'], False) True False SVM
# (234, '"', ['Batman', '"', 'Batman.Still,'], ["isn't", 'bad', 'at'], False) True False SVM
# (249, 'Dances With Wolves', ['become', 'to', 'experiences'], ['?please', 'visit', "Chad'z"], True) False True SVM
# (274, 'Batman', ['Dowling', 'Chuck', '1997'], ['(1989)', '***', 'out'], True) False True SVM
# (278, 'I', ['oscar.', 'an', 'won'], ['could', 'just', 'imagine'], False) True False SVM
# (296, 'I', ['movie.', 'this', 'about'], ['have', 'thesinking', 'feeling'], False) True False SVM
# (304, 'Annie Hall', ['of"', 'exception', 'the'], [',"', 'no', 'other'], True) False True SVM
# (321, 'of"', ['version', 'his', 'is'], ['1984', '"', 'or'], False) True False SVM
# (355, 'Midnight Cowboy "', ['"', 'symbolicof', 'is'], ['-', 'there', 'is'], False) True False SVM
# (438, "that there's no", ['itclear', 'made', 'I'], ['difference', 'between', '"'], False) True False SVM
# (441, 'Hellraiser " or', ['"', 'thananother', 'better'], ['"', 'Halloween', '"'], False) True False SVM
# (444, '2001: A Space Odyssey', ['', '', ''], ["Chad'z", 'rating:', '****'], True) False True SVM
# (449, 'makes', ['answer.What', 'correct', 'one'], ['"', '2001:', 'A'], False) True False SVM
# (457, 'Scream', ['', '', ''], ["Chad'z", 'rating:', '***'], True) False True SVM
# (496, "that, '", ['importantthan', 'more', 'but'], ['Platoon', "'", 'forced'], False) True False SVM
# (497, 'Total Recall', ['', '', ''], ['A', 'Film', 'Review'], True) False True SVM
# (503, 'Speed 2', ['Ex.', 'enjoyable.', 'of'], [',', "TheDevil's", 'Own'], True) False True SVM
# (504, "TheDevil's Own", [',', '2', 'Speed'], ['*', '=', 'Poor'], True) False True SVM
# (505, 'Congo', ['Ex.', 'picture.', 'unbearable'], [',', 'Batmanand', 'Robin'], True) False True SVM
# (506, 'Batmanand Robin', [',', 'Congo', 'Ex.'], ['Copyright', '1997', 'Jesse'], True) False True SVM
# (530, 'Raiders of the Lost Ark', ['Spielberg', 'Steven', 'by:'], ['(1981)', 'is', 'the'], True) False True SVM
# (538, 'Air Force One , Pulp Fiction', ['(', 'Excellent', '****Excellent****'], [')***', 'Good', '('], True) False True SVM
# (539, 'Jurrasic Park , Resivour Dogs', ['(', 'Good', ')***'], [')**', 'Fair', '('], True) False True SVM
# (540, 'Con Air', ['(', 'Fair', ')**'], [',', 'The', "Devil's"], True) False True SVM
# (541, "The Devil's Own", [',', 'Air', 'Con'], [')*', 'Poor', '('], True) False True SVM
# (542, 'Spawn', ['(', 'Poor', ')*'], [',', '8', 'Heads'], True) False True SVM
# (543, 'Batman and Robin', ['(', 'Horrendous', 'dufflebag)0'], [',', 'Congo', ')Copyright'], True) False True SVM
# (544, 'Congo', [',', 'Robin', 'and'], [')Copyright', '1997', 'Jesse'], True) False True SVM
# (555, 'Scream', ['', '', ''], ['(1997)Starring', 'Neve', 'Campbell,'], True) False True SVM
# (556, 'Scream: The Sequel', ['for', 'waiting', "I'mjust"], ['.', '', ''], True) False True SVM
# (602, "DeerHunter '. '", ['The', "'", 'to'], ['True', 'Grit', "'"], False) True False SVM
# (643, '2001:Space Odyssey', ['recommend', 'I', 'pacing.'], ['because', 'it', 'is'], True) False True SVM
# (655, 'Nightmare on Elm Street', ['knownis', 'most', 'his'], ['.', 'In', 'Scream'], True) False True SVM
# (656, 'Scream', ['In', '.', 'Street'], ['Craven', 'knows', 'that'], True) False True SVM
# (657, 'Scream', ['in', 'effort', 'good'], ['.', 'It', 'was'], True) False True SVM
# (658, 'Scream', ['miss', "Don't", 'film.'], ['.', 'And', 'as'], True) False True SVM
# (669, 'Legend', ['', '', ''], ['(1985)A', 'movie', 'review'], True) False True SVM
# (683, 'Scream', ['mean"', 'this', 'Does'], ['"\'s', 'plot', 'will'], True) False True SVM
# (697, 'Jaws', ['whilemaking', 'learned', 'he'], ['-', 'our', 'imagination'], True) False True SVM
# (698, 'Jaws', ['films.', 'great', 'more'], [':', 'A+', 'Jurassic'], True) False True SVM
# (699, 'Jurassic Park', ['A+', ':', 'Jaws'], [':', 'C+', 'The'], True) False True SVM
# (700, 'The Lost World', ['C+', ':', 'Park'], [':', 'Jurassic', 'Park'], True) False True SVM
# (701, 'Jurassic Park', [':', 'World', 'Lost'], [':', 'B+', ''], True) False True SVM
# (712, 'Raiders Of The LostArk', ['athttp://www.gafieldlib.com/yanews/july97/max/max.html', 'reviews', "Max's"], ['could', 'be', 'called'], True) False True SVM
# (713, 'Raiders Of The Lost Ark', ['pray.', 'and', 'projects'], [':', 'A+', 'Indiana'], True) False True SVM
# (714, 'Indiana Jones And The Temple Of Doom', ['A+', ':', 'Ark'], [':', 'F', 'Indiana'], True) False True SVM
# (715, 'Indiana Jones And The Last Crusade', ['F', ':', 'Doom'], [':', 'B+', ''], True) False True SVM
# (726, 'Patriot Games', ['', '', ''], ['(1992)Grade:', '44"', 'Patriot'], True) False True SVM
# (734, 'tries', ['"', 'PatriotGames', 'lately?""'], ['to', 'create', 'tension'], False) True False SVM
# (751, 'Patton', ['', '', ''], ['(1970)Grade:', '89"', 'Patton'], True) False True SVM
# (763, 'Julia', ['', '', ''], ['(1977)Grade:', '78"', 'Julia'], True) False True SVM
# (775, '"', ['her.Still,', 'to', 'figure'], ['Julia', '"', 'is'], False) True False SVM
# (777, 'Romeo And Juliet', ["Luhrman's", 'andBaz', 'brilliant,'], ['colorful', 'and', 'deeply'], True) False True SVM
# (778, 'Sense AndSensibility', ['herself...(see', 'Thompson', 'Emma'], [')Vincent', 'Merlaud', ''], True) False True SVM
# (789, 'Rebecca', ['', '', ''], ['(1940)Grade:', '97', 'Quiz'], True) False True SVM
# (798, 'in the', ['also', 'is', '"'], ['running.', 'Other', 'films'], False) True False SVM
# (807, 'Alien', ['', '', ''], ["Chad'z", 'rating:', '**1/2'], True) False True SVM
# (809, '2001', ['in"', 'used', 'technique'], ['")', 'to', 'investigate'], True) False True SVM
# (821, 'Eraserhead', ['', '', ''], ['*', '*', '*'], True) False True SVM
# (839, 'Eraserhead "', ['"', 'life.', 'anunpleasant'], ['could', 'probably', 'be'], False) True False SVM
# (843, 'Time Bandits', ['Patterson', 'Kevin', 'by'], ['*', '*', '*PG,'], True) False True SVM
# (860, 'succeeds at', ['"', 'Bandits', 'Time'], ['both', 'romanticizing', 'and'], False) True False SVM
# (885, 'Scream', ['of"', 'downside', 'the'], [',"', 'which', 'is'], True) False True SVM
# (903, 'with', ['opens', '"', 'Scream'], ['one', 'of', 'the'], False) True False SVM
# (905, 'Aliens', ['', '', ''], ["Chad'z", 'rating:', '**'], True) False True SVM
# (924, 'which', ['To', '"', '.'], ['I', 'say,', '"THE'], False) True False SVM
# (927, 'which I', ['To', '"', '.'], ['say,', '"THE', 'greatest'], False) True False SVM
# (930, 'Days of Heaven', ['', '', ''], ['(1978)Grade:', '93The', 'documentary'], True) False True SVM
# (937, '"lavished more screen', ['Cinematography', 'of', 'Art'], ['time', 'on', '"'], False) True False SVM
# (942, 'to be." Days', ['appear', 'they', 'as'], ['ofHeaven', '"', 'was'], False) True False SVM
# (947, 'Alien: Resurrection', ['', '', ''], ['(Aliens', '4)', 'Directed'], True) False True SVM
# (948, '_Aliens_', ['stylefor', 'different', 'another'], ['.', 'The', 'fact'], True) False True SVM
# (949, '_Alien_', ['an', 'see', 'to'], ['film,', 'this', 'is'], True) False True SVM
# (960, 'Aliens', ['', '', ''], ['(1986)Review', 'by', 'Laurence'], True) False True SVM
# (961, 'Citizen Kane', ['was', 'it', 'dramas,'], [',', 'with', 'arthouse'], True) False True SVM
# (962, 'Forrest Gump', ['did', 'as', 'event,'], ['four', 'yearsago.With', 'action'], True) False True SVM
# (963, 'Alien', ['parent,', 'equally-innovative', "it's"], ['(1979).', 'Directed', 'andwritten'], True) False True SVM
# (964, 'The Terminator', ['sci-fithriller', 'his', 'to'], ['(1984).While', 'the', 'original'], True) False True SVM
# (965, 'T2: Judgement Day', ['film,', 'Cameron', 'another'], [',', 'in', '1991.'], True) False True SVM
# (977, 'Hercules', ['(especially', 'releases...', 'Disney'], [')...', 'emotion.All', 'the'], True) False True SVM
# (978, 'Beauty & the Beast', ["sinceDisney's", 'Not', 'together.'], ['has', 'there', 'been'], True) False True SVM
# (990, 'Alien: Resurrection', ['', '', ''], ["won't", 'revive', 'creatively'], True) False True SVM
# (994, 'Alien:Resurrection', ['mess,"', 'latest', 'this'], [',"', 'slithering', 'into'], True) False True SVM
# (997, 'The Poiseidon Adventure', ['from"', 'directly', 'quoted'], ['"--but', 'without', 'the'], True) False True SVM
# (1018, 'Seven', ['Fincher(`', 'David', 'like'], ["')'s", 'part', 'three,'], True) False True SVM
# (1019, 'Aliens', ['`', "JamesCameron's", 'in'], ["'.", 'But', 'I'], True) False True SVM
# (1020, 'Independence Day', ['`', 'in', 'hear'], ["'.", "They're", 'uniqueducks'], True) False True SVM
# (1022, 'aesthetically', ['artfullymade,', 'is', "'"], ['pretty', 'like', 'David'], False) True False SVM
# (1032, 'Anastasia', ['', '', ''], ['a', 'reviewBy', 'Jeremiah'], True) False True SVM
# (1033, 'Anastasia', ['showingof', 'late', 'the'], ['at', 'one', 'of'], True) False True SVM
# (1034, 'Anastasia', ['digress.', 'I', 'but'], ['is', 'the', 'first'], True) False True SVM
# (1035, 'The Secret of Nimh', ['entertainment,including', 'animated', 'of'], [',', 'An', 'American'], True) False True SVM
# (1036, 'An American Tail', [',', 'Nimh', 'of'], [',', 'and', 'All'], True) False True SVM
# (1037, 'All Dogs Go To Heaven', ['and', ',', 'Tail'], [',just', 'to', 'name'], True) False True SVM
# (1038, 'Hercules', ['(', 'films.', 'Animated'], ['and', 'Pocahontas', ').At'], True) False True SVM
# (1039, 'Pocahontas', ['and', 'Hercules', '('], [').At', 'first', 'glance,'], True) False True SVM
# (1040, 'The Black Cauldron', ['of', 'reminded', 'was'], ['a', 'bit,where', 'armies'], True) False True SVM
# (1041, 'Anastaisa', ['if', 'besurprised', 'would'], ['grosses', 'in', 'the'], True) False True SVM
# (1042, 'Alladin', ['in', 'parrot', 'The'], ['as', 'played', 'by'], True) False True SVM
# (1068, 'Alien: Resurrection', ['', '', ''], ['(1997)Sigourney', 'Weaver,', 'Winona'], True) False True SVM
# (1073, 'Resurrection', ['alliance."', 'uneasy', 'an'], ['\x12s"', 'action', 'sequences'], True) False True SVM
# (1135, 'Alien', ['', '', ''], ['(1979)Rated', 'R', 'for'], True) False True SVM
# (1163, 'Aliens', ['', '', ''], ['(1986)Rated', 'R', 'for'], True) False True SVM
# (1174, 'Blade Runner', ['when', 'was', 'outmid-day'], ['was', 'released.', 'Today'], True) False True SVM
# (1175, 'Alien Resurrection', ['-', 'further', 'any'], ['is', '_great_.', 'Webbies'], True) False True SVM
# (1176, 'English Patient', ['the', "Itisn't", 'rating.'], ['(but', 'maybe', 'there'], True) False True SVM
# (1177, 'Bride of Dracula', ['the', 'with', 'inlove'], ['(I', 'still', 'fall'], True) False True SVM
# (1178, 'Alien Resurrection', ['love', 'yagotta', 'then'], ['.', 'It', 'has'], True) False True SVM
# (1179, 'Zorro', ['for', 'was', 'lot'], ['.', 'Yes,', 'Zorro'], True) False True SVM
# (1180, 'Zorro', ['Yes,', '.', 'Zorro'], ['.', 'I', 'kept'], True) False True SVM
# (1191, 'Alien Resurrection', ['', '', ''], ['Director:', 'Jean-Pierre', 'JeunetStarring:'], True) False True SVM
# (1192, 'Alien 3', ['in', 'died', 'she'], ['.', 'But', 'those'], True) False True SVM
# (1193, 'AlienResurrection', ['that', 'thing', 'stuff.Another'], ['offers', 'that', 'the'], True) False True SVM
# (1194, 'Alien 3', ['After', 'now?', 'series'], [',', 'we', 'were'], True) False True SVM
# (1205, 'Anastasia', ['', '', ''], ['Directors:', 'Don', 'Bluth'], True) False True SVM
# (1208, 'French Kiss', ['in', 'character', 'her'], [')', 'and', 'plenty'], True) False True SVM
# (1215, 'front ofimpressionist backgrounds)Somehow,', ['in', 'dance', 'to'], ['the', '"', 'Magic'], False) True False SVM
# (1219, 'Alien Resurrection', ['', '', ''], ['(1997)Rated', 'R', 'for'], True) False True SVM
# (1230, 'Anastasia', ['', '', ''], ['(1997)Rating:', '3.0', 'stars'], True) False True SVM
# (1241, 'Alien', ['', '', ''], ['(1979)A', 'movie', 'review'], True) False True SVM
# (1272, 'LOST CHILDREN .', ['OF', 'CITY', 'masterpiece'], ['His', 'strengths', 'are'], False) True False SVM
# (20, '"Alien"', ['the', 'of', 'any'], ['films.Weaver,', 'perhaps', 'inspired'], True) False True Random Forest
# (40, '*', ['*', 'Kelsey*', 'Benjamin'], ['*', '(out', 'of'], False) True False Random Forest
# (107, "'s MUCH ADO ABOUT NOTHING", ['KennethBranagh', 'in', 'onscreen'], ['.', 'But', 'if'], True) False True Random Forest
# (123, 'ANNA KARENINAA film review', ['', '', ''], ['by', 'James', 'BerardinelliCopyright'], True) False True Random Forest
# (125, "'s (IMMORTAL BELOVED)", ['Rose', ',Bernard', 'KARENINA'], ['attempt', 'to', 'bring'], True) False True Random Forest
# (135, "'s HAMLET", ['Branagh', 'Kenneth', 'since'], ['.', 'Ballroominteriors,', 'landscapes,'], True) False True Random Forest
# (140, 'TO 10):', ['(0', 'BerardinelliRATING', 'James'], ['5.5Alternative', 'Scale:', '**'], False) True False Random Forest
# (166, 'I', ['though', '--', 'Gertrude'], ['must', "confessI'm", 'still'], False) True False Random Forest
# (181, '"Amadeus"', ['glance,', 'first', 'Forman.At'], ['seems', 'like', 'a'], True) False True Random Forest
# (182, '"Amadeus."', ['of', 'view', 'my'], ['After', 'Emperor', 'Joseph'], True) False True Random Forest
# (183, '"One Flew Over The Cuckoo\'sNest," "ThePeople Vs. Larry Flynt"', ['Forman:', 'by', '[also'], [']visit', "Chad'z", 'Movie'], True) False True Random Forest
# (209, 'and Cooper RedwineCopyright', ['Ivana', 'by', 'review'], ['1997', 'Ivana', 'and'], False) True False Random Forest
# (222, 'Honeymooners ,"', ['The', '"', 'movies,'], ['all', 'those', 'big'], False) True False Random Forest
# (234, '"', ['Batman', '"', 'Batman.Still,'], ["isn't", 'bad', 'at'], False) True False Random Forest
# (249, 'Dances With Wolves', ['become', 'to', 'experiences'], ['?please', 'visit', "Chad'z"], True) False True Random Forest
# (259, 'Chad Polenz***1/2', ['1997', 'PolenzCopyright', 'Chad'], ['(out', 'of', '4'], False) True False Random Forest
# (278, 'I', ['oscar.', 'an', 'won'], ['could', 'just', 'imagine'], False) True False Random Forest
# (296, 'I', ['movie.', 'this', 'about'], ['have', 'thesinking', 'feeling'], False) True False Random Forest
# (304, 'Annie Hall', ['of"', 'exception', 'the'], [',"', 'no', 'other'], True) False True Random Forest
# (321, 'of"', ['version', 'his', 'is'], ['1984', '"', 'or'], False) True False Random Forest
# (337, 'Polenz**** (out', ['Chad', '1997', 'PolenzCopyright'], ['of', '4', '='], False) True False Random Forest
# (355, 'Midnight Cowboy "', ['"', 'symbolicof', 'is'], ['-', 'there', 'is'], False) True False Random Forest
# (441, 'Hellraiser " or', ['"', 'thananother', 'better'], ['"', 'Halloween', '"'], False) True False Random Forest
# (444, '2001: A Space Odyssey', ['', '', ''], ["Chad'z", 'rating:', '****'], True) False True Random Forest
# (449, 'makes', ['answer.What', 'correct', 'one'], ['"', '2001:', 'A'], False) True False Random Forest
# (457, 'Scream', ['', '', ''], ["Chad'z", 'rating:', '***'], True) False True Random Forest
# (496, "that, '", ['importantthan', 'more', 'but'], ['Platoon', "'", 'forced'], False) True False Random Forest
# (497, 'Total Recall', ['', '', ''], ['A', 'Film', 'Review'], True) False True Random Forest
# (503, 'Speed 2', ['Ex.', 'enjoyable.', 'of'], [',', "TheDevil's", 'Own'], True) False True Random Forest
# (505, 'Congo', ['Ex.', 'picture.', 'unbearable'], [',', 'Batmanand', 'Robin'], True) False True Random Forest
# (556, 'Scream: The Sequel', ['for', 'waiting', "I'mjust"], ['.', '', ''], True) False True Random Forest
# (645, 'was', ['what', 'reflects', '2001'], ['current', 'then,', 'and'], False) True False Random Forest
# (655, 'Nightmare on Elm Street', ['knownis', 'most', 'his'], ['.', 'In', 'Scream'], True) False True Random Forest
# (656, 'Scream', ['In', '.', 'Street'], ['Craven', 'knows', 'that'], True) False True Random Forest
# (657, 'Scream', ['in', 'effort', 'good'], ['.', 'It', 'was'], True) False True Random Forest
# (658, 'Scream', ['miss', "Don't", 'film.'], ['.', 'And', 'as'], True) False True Random Forest
# (676, 'Yegulalp[NB: This review', ['Serdar', 'by', '1997'], ['is', 'designed', 'to'], False) True False Random Forest
# (683, 'Scream', ['mean"', 'this', 'Does'], ['"\'s', 'plot', 'will'], True) False True Random Forest
# (697, 'Jaws', ['whilemaking', 'learned', 'he'], ['-', 'our', 'imagination'], True) False True Random Forest
# (710, 'original trailer for', ['the', 'In', '('], ['Psychothere', 'is', 'a'], False) True False Random Forest
# (712, 'Raiders Of The LostArk', ['athttp://www.gafieldlib.com/yanews/july97/max/max.html', 'reviews', "Max's"], ['could', 'be', 'called'], True) False True Random Forest
# (734, 'tries', ['"', 'PatriotGames', 'lately?""'], ['to', 'create', 'tension'], False) True False Random Forest
# (775, '"', ['her.Still,', 'to', 'figure'], ['Julia', '"', 'is'], False) True False Random Forest
# (777, 'Romeo And Juliet', ["Luhrman's", 'andBaz', 'brilliant,'], ['colorful', 'and', 'deeply'], True) False True Random Forest
# (778, 'Sense AndSensibility', ['herself...(see', 'Thompson', 'Emma'], [')Vincent', 'Merlaud', ''], True) False True Random Forest
# (798, 'in the', ['also', 'is', '"'], ['running.', 'Other', 'films'], False) True False Random Forest
# (807, 'Alien', ['', '', ''], ["Chad'z", 'rating:', '**1/2'], True) False True Random Forest
# (809, '2001', ['in"', 'used', 'technique'], ['")', 'to', 'investigate'], True) False True Random Forest
# (839, 'Eraserhead "', ['"', 'life.', 'anunpleasant'], ['could', 'probably', 'be'], False) True False Random Forest
# (857, '1981Directed by', ['*PG,', '*', '*'], ['Terry', 'Gilliam.', 'Written'], False) True False Random Forest
# (860, 'succeeds at', ['"', 'Bandits', 'Time'], ['both', 'romanticizing', 'and'], False) True False Random Forest
# (885, 'Scream', ['of"', 'downside', 'the'], [',"', 'which', 'is'], True) False True Random Forest
# (903, 'with', ['opens', '"', 'Scream'], ['one', 'of', 'the'], False) True False Random Forest
# (905, 'Aliens', ['', '', ''], ["Chad'z", 'rating:', '**'], True) False True Random Forest
# (924, 'which', ['To', '"', '.'], ['I', 'say,', '"THE'], False) True False Random Forest
# (927, 'which I', ['To', '"', '.'], ['say,', '"THE', 'greatest'], False) True False Random Forest
# (937, '"lavished more screen', ['Cinematography', 'of', 'Art'], ['time', 'on', '"'], False) True False Random Forest
# (942, 'to be." Days', ['appear', 'they', 'as'], ['ofHeaven', '"', 'was'], False) True False Random Forest
# (947, 'Alien: Resurrection', ['', '', ''], ['(Aliens', '4)', 'Directed'], True) False True Random Forest
# (948, '_Aliens_', ['stylefor', 'different', 'another'], ['.', 'The', 'fact'], True) False True Random Forest
# (949, '_Alien_', ['an', 'see', 'to'], ['film,', 'this', 'is'], True) False True Random Forest
# (961, 'Citizen Kane', ['was', 'it', 'dramas,'], [',', 'with', 'arthouse'], True) False True Random Forest
# (962, 'Forrest Gump', ['did', 'as', 'event,'], ['four', 'yearsago.With', 'action'], True) False True Random Forest
# (965, 'T2: Judgement Day', ['film,', 'Cameron', 'another'], [',', 'in', '1991.'], True) False True Random Forest
# (973, 'Directed', ['(1979).', 'Alien', 'parent,'], ['andwritten', 'by', 'James'], False) True False Random Forest
# (977, 'Hercules', ['(especially', 'releases...', 'Disney'], [')...', 'emotion.All', 'the'], True) False True Random Forest
# (978, 'Beauty & the Beast', ["sinceDisney's", 'Not', 'together.'], ['has', 'there', 'been'], True) False True Random Forest
# (990, 'Alien: Resurrection', ['', '', ''], ["won't", 'revive', 'creatively'], True) False True Random Forest
# (994, 'Alien:Resurrection', ['mess,"', 'latest', 'this'], [',"', 'slithering', 'into'], True) False True Random Forest
# (997, 'The Poiseidon Adventure', ['from"', 'directly', 'quoted'], ['"--but', 'without', 'the'], True) False True Random Forest
# (1018, 'Seven', ['Fincher(`', 'David', 'like'], ["')'s", 'part', 'three,'], True) False True Random Forest
# (1019, 'Aliens', ['`', "JamesCameron's", 'in'], ["'.", 'But', 'I'], True) False True Random Forest
# (1020, 'Independence Day', ['`', 'in', 'hear'], ["'.", "They're", 'uniqueducks'], True) False True Random Forest
# (1022, 'aesthetically', ['artfullymade,', 'is', "'"], ['pretty', 'like', 'David'], False) True False Random Forest
# (1032, 'Anastasia', ['', '', ''], ['a', 'reviewBy', 'Jeremiah'], True) False True Random Forest
# (1033, 'Anastasia', ['showingof', 'late', 'the'], ['at', 'one', 'of'], True) False True Random Forest
# (1034, 'Anastasia', ['digress.', 'I', 'but'], ['is', 'the', 'first'], True) False True Random Forest
# (1035, 'The Secret of Nimh', ['entertainment,including', 'animated', 'of'], [',', 'An', 'American'], True) False True Random Forest
# (1036, 'An American Tail', [',', 'Nimh', 'of'], [',', 'and', 'All'], True) False True Random Forest
# (1037, 'All Dogs Go To Heaven', ['and', ',', 'Tail'], [',just', 'to', 'name'], True) False True Random Forest
# (1040, 'The Black Cauldron', ['of', 'reminded', 'was'], ['a', 'bit,where', 'armies'], True) False True Random Forest
# (1041, 'Anastaisa', ['if', 'besurprised', 'would'], ['grosses', 'in', 'the'], True) False True Random Forest
# (1048, 'Alladin as played', ['in', 'parrot', 'The'], ['by', 'Gilbert', 'Gottfried'], False) True False Random Forest
# (1073, 'Resurrection', ['alliance."', 'uneasy', 'an'], ['\x12s"', 'action', 'sequences'], True) False True Random Forest
# (1097, '60% of ANASTASIA', ["You'llsee", '.', 'CANDLESHOE'], ['there.Dave', 'ThompsenEmail', ':'], False) True False Random Forest
# (1174, 'Blade Runner', ['when', 'was', 'outmid-day'], ['was', 'released.', 'Today'], True) False True Random Forest
# (1175, 'Alien Resurrection', ['-', 'further', 'any'], ['is', '_great_.', 'Webbies'], True) False True Random Forest
# (1176, 'English Patient', ['the', "Itisn't", 'rating.'], ['(but', 'maybe', 'there'], True) False True Random Forest
# (1177, 'Bride of Dracula', ['the', 'with', 'inlove'], ['(I', 'still', 'fall'], True) False True Random Forest
# (1178, 'Alien Resurrection', ['love', 'yagotta', 'then'], ['.', 'It', 'has'], True) False True Random Forest
# (1179, 'Zorro', ['for', 'was', 'lot'], ['.', 'Yes,', 'Zorro'], True) False True Random Forest
# (1180, 'Zorro', ['Yes,', '.', 'Zorro'], ['.', 'I', 'kept'], True) False True Random Forest
# (1191, 'Alien Resurrection', ['', '', ''], ['Director:', 'Jean-Pierre', 'JeunetStarring:'], True) False True Random Forest
# (1192, 'Alien 3', ['in', 'died', 'she'], ['.', 'But', 'those'], True) False True Random Forest
# (1193, 'AlienResurrection', ['that', 'thing', 'stuff.Another'], ['offers', 'that', 'the'], True) False True Random Forest
# (1194, 'Alien 3', ['After', 'now?', 'series'], [',', 'we', 'were'], True) False True Random Forest
# (1205, 'Anastasia', ['', '', ''], ['Directors:', 'Don', 'Bluth'], True) False True Random Forest
# (1215, 'front ofimpressionist backgrounds)Somehow,', ['in', 'dance', 'to'], ['the', '"', 'Magic'], False) True False Random Forest
# (1272, 'LOST CHILDREN .', ['OF', 'CITY', 'masterpiece'], ['His', 'strengths', 'are'], False) True False Random Forest
# (1298, 'second film, is', ['the', '(1986),', 'ALIENS'], ['a', 'classicas', 'well.'], False) True False Random Forest
# (1307, 'Maria', ['1', '9917.html-rwx------', '18:43'], ['None', '4465', 'Feb'], False) True False Random Forest
# (1308, '17 18:43', ['Feb', '4690', 'None'], ['9729.html-rwx------', '1', 'Maria'], False) True False Random Forest
# (1309, 'None 5915', ['Maria', '1', '9646.html-rwx------'], ['Feb', '17', '18:43'], False) True False Random Forest
# (1310, 'Maria None 4127', ['1', '8669.html-rwx------', '18:43'], ['Feb', '17', '18:43'], False) True False Random Forest
# (1311, '1', ['8005.html-rwx------', '18:43', '17'], ['Maria', 'None', '3234'], False) True False Random Forest
# (1312, '9494.html-rwx------', ['18:43', '17', 'Feb'], ['1', 'Maria', 'None'], False) True False Random Forest
# (1313, 'Feb 17', ['588', 'None', 'Maria'], ['18:43', '9915.html-rwx------', '1'], False) True False Random Forest
# (1314, 'None', ['Maria', '1', '9180.html-rwx------'], ['1695', 'Feb', '17'], False) True False Random Forest
# (1315, 'Feb', ['4042', 'None', 'Maria'], ['17', '18:43', '8157.html-rwx------'], False) True False Random Forest
# (1316, 'Maria', ['1', '9917.html-rwx------', '18:43'], ['None', '4465', 'Feb'], False) True False Random Forest
# (20, '"Alien"', ['the', 'of', 'any'], ['films.Weaver,', 'perhaps', 'inspired'], True) False True ExtraTrees
# (40, '*', ['*', 'Kelsey*', 'Benjamin'], ['*', '(out', 'of'], False) True False ExtraTrees
# (107, "'s MUCH ADO ABOUT NOTHING", ['KennethBranagh', 'in', 'onscreen'], ['.', 'But', 'if'], True) False True ExtraTrees
# (123, 'ANNA KARENINAA film review', ['', '', ''], ['by', 'James', 'BerardinelliCopyright'], True) False True ExtraTrees
# (125, "'s (IMMORTAL BELOVED)", ['Rose', ',Bernard', 'KARENINA'], ['attempt', 'to', 'bring'], True) False True ExtraTrees
# (135, "'s HAMLET", ['Branagh', 'Kenneth', 'since'], ['.', 'Ballroominteriors,', 'landscapes,'], True) False True ExtraTrees
# (140, 'TO 10):', ['(0', 'BerardinelliRATING', 'James'], ['5.5Alternative', 'Scale:', '**'], False) True False ExtraTrees
# (166, 'I', ['though', '--', 'Gertrude'], ['must', "confessI'm", 'still'], False) True False ExtraTrees
# (181, '"Amadeus"', ['glance,', 'first', 'Forman.At'], ['seems', 'like', 'a'], True) False True ExtraTrees
# (182, '"Amadeus."', ['of', 'view', 'my'], ['After', 'Emperor', 'Joseph'], True) False True ExtraTrees
# (183, '"One Flew Over The Cuckoo\'sNest," "ThePeople Vs. Larry Flynt"', ['Forman:', 'by', '[also'], [']visit', "Chad'z", 'Movie'], True) False True ExtraTrees
# (209, 'and Cooper RedwineCopyright', ['Ivana', 'by', 'review'], ['1997', 'Ivana', 'and'], False) True False ExtraTrees
# (222, 'Honeymooners ,"', ['The', '"', 'movies,'], ['all', 'those', 'big'], False) True False ExtraTrees
# (234, '"', ['Batman', '"', 'Batman.Still,'], ["isn't", 'bad', 'at'], False) True False ExtraTrees
# (249, 'Dances With Wolves', ['become', 'to', 'experiences'], ['?please', 'visit', "Chad'z"], True) False True ExtraTrees
# (259, 'Chad Polenz***1/2', ['1997', 'PolenzCopyright', 'Chad'], ['(out', 'of', '4'], False) True False ExtraTrees
# (278, 'I', ['oscar.', 'an', 'won'], ['could', 'just', 'imagine'], False) True False ExtraTrees
# (296, 'I', ['movie.', 'this', 'about'], ['have', 'thesinking', 'feeling'], False) True False ExtraTrees
# (304, 'Annie Hall', ['of"', 'exception', 'the'], [',"', 'no', 'other'], True) False True ExtraTrees
# (321, 'of"', ['version', 'his', 'is'], ['1984', '"', 'or'], False) True False ExtraTrees
# (337, 'Polenz**** (out', ['Chad', '1997', 'PolenzCopyright'], ['of', '4', '='], False) True False ExtraTrees
# (355, 'Midnight Cowboy "', ['"', 'symbolicof', 'is'], ['-', 'there', 'is'], False) True False ExtraTrees
# (441, 'Hellraiser " or', ['"', 'thananother', 'better'], ['"', 'Halloween', '"'], False) True False ExtraTrees
# (444, '2001: A Space Odyssey', ['', '', ''], ["Chad'z", 'rating:', '****'], True) False True ExtraTrees
# (449, 'makes', ['answer.What', 'correct', 'one'], ['"', '2001:', 'A'], False) True False ExtraTrees
# (457, 'Scream', ['', '', ''], ["Chad'z", 'rating:', '***'], True) False True ExtraTrees
# (496, "that, '", ['importantthan', 'more', 'but'], ['Platoon', "'", 'forced'], False) True False ExtraTrees
# (497, 'Total Recall', ['', '', ''], ['A', 'Film', 'Review'], True) False True ExtraTrees
# (503, 'Speed 2', ['Ex.', 'enjoyable.', 'of'], [',', "TheDevil's", 'Own'], True) False True ExtraTrees
# (505, 'Congo', ['Ex.', 'picture.', 'unbearable'], [',', 'Batmanand', 'Robin'], True) False True ExtraTrees
# (556, 'Scream: The Sequel', ['for', 'waiting', "I'mjust"], ['.', '', ''], True) False True ExtraTrees
# (645, 'was', ['what', 'reflects', '2001'], ['current', 'then,', 'and'], False) True False ExtraTrees
# (655, 'Nightmare on Elm Street', ['knownis', 'most', 'his'], ['.', 'In', 'Scream'], True) False True ExtraTrees
# (656, 'Scream', ['In', '.', 'Street'], ['Craven', 'knows', 'that'], True) False True ExtraTrees
# (657, 'Scream', ['in', 'effort', 'good'], ['.', 'It', 'was'], True) False True ExtraTrees
# (658, 'Scream', ['miss', "Don't", 'film.'], ['.', 'And', 'as'], True) False True ExtraTrees
# (676, 'Yegulalp[NB: This review', ['Serdar', 'by', '1997'], ['is', 'designed', 'to'], False) True False ExtraTrees
# (683, 'Scream', ['mean"', 'this', 'Does'], ['"\'s', 'plot', 'will'], True) False True ExtraTrees
# (697, 'Jaws', ['whilemaking', 'learned', 'he'], ['-', 'our', 'imagination'], True) False True ExtraTrees
# (710, 'original trailer for', ['the', 'In', '('], ['Psychothere', 'is', 'a'], False) True False ExtraTrees
# (712, 'Raiders Of The LostArk', ['athttp://www.gafieldlib.com/yanews/july97/max/max.html', 'reviews', "Max's"], ['could', 'be', 'called'], True) False True ExtraTrees
# (734, 'tries', ['"', 'PatriotGames', 'lately?""'], ['to', 'create', 'tension'], False) True False ExtraTrees
# (775, '"', ['her.Still,', 'to', 'figure'], ['Julia', '"', 'is'], False) True False ExtraTrees
# (777, 'Romeo And Juliet', ["Luhrman's", 'andBaz', 'brilliant,'], ['colorful', 'and', 'deeply'], True) False True ExtraTrees
# (778, 'Sense AndSensibility', ['herself...(see', 'Thompson', 'Emma'], [')Vincent', 'Merlaud', ''], True) False True ExtraTrees
# (798, 'in the', ['also', 'is', '"'], ['running.', 'Other', 'films'], False) True False ExtraTrees
# (807, 'Alien', ['', '', ''], ["Chad'z", 'rating:', '**1/2'], True) False True ExtraTrees
# (809, '2001', ['in"', 'used', 'technique'], ['")', 'to', 'investigate'], True) False True ExtraTrees
# (839, 'Eraserhead "', ['"', 'life.', 'anunpleasant'], ['could', 'probably', 'be'], False) True False ExtraTrees
# (857, '1981Directed by', ['*PG,', '*', '*'], ['Terry', 'Gilliam.', 'Written'], False) True False ExtraTrees
# (860, 'succeeds at', ['"', 'Bandits', 'Time'], ['both', 'romanticizing', 'and'], False) True False ExtraTrees
# (885, 'Scream', ['of"', 'downside', 'the'], [',"', 'which', 'is'], True) False True ExtraTrees
# (903, 'with', ['opens', '"', 'Scream'], ['one', 'of', 'the'], False) True False ExtraTrees
# (905, 'Aliens', ['', '', ''], ["Chad'z", 'rating:', '**'], True) False True ExtraTrees
# (924, 'which', ['To', '"', '.'], ['I', 'say,', '"THE'], False) True False ExtraTrees
# (927, 'which I', ['To', '"', '.'], ['say,', '"THE', 'greatest'], False) True False ExtraTrees
# (937, '"lavished more screen', ['Cinematography', 'of', 'Art'], ['time', 'on', '"'], False) True False ExtraTrees
# (942, 'to be." Days', ['appear', 'they', 'as'], ['ofHeaven', '"', 'was'], False) True False ExtraTrees
# (947, 'Alien: Resurrection', ['', '', ''], ['(Aliens', '4)', 'Directed'], True) False True ExtraTrees
# (948, '_Aliens_', ['stylefor', 'different', 'another'], ['.', 'The', 'fact'], True) False True ExtraTrees
# (949, '_Alien_', ['an', 'see', 'to'], ['film,', 'this', 'is'], True) False True ExtraTrees
# (961, 'Citizen Kane', ['was', 'it', 'dramas,'], [',', 'with', 'arthouse'], True) False True ExtraTrees
# (962, 'Forrest Gump', ['did', 'as', 'event,'], ['four', 'yearsago.With', 'action'], True) False True ExtraTrees
# (965, 'T2: Judgement Day', ['film,', 'Cameron', 'another'], [',', 'in', '1991.'], True) False True ExtraTrees
# (973, 'Directed', ['(1979).', 'Alien', 'parent,'], ['andwritten', 'by', 'James'], False) True False ExtraTrees
# (977, 'Hercules', ['(especially', 'releases...', 'Disney'], [')...', 'emotion.All', 'the'], True) False True ExtraTrees
# (978, 'Beauty & the Beast', ["sinceDisney's", 'Not', 'together.'], ['has', 'there', 'been'], True) False True ExtraTrees
# (990, 'Alien: Resurrection', ['', '', ''], ["won't", 'revive', 'creatively'], True) False True ExtraTrees
# (994, 'Alien:Resurrection', ['mess,"', 'latest', 'this'], [',"', 'slithering', 'into'], True) False True ExtraTrees
# (997, 'The Poiseidon Adventure', ['from"', 'directly', 'quoted'], ['"--but', 'without', 'the'], True) False True ExtraTrees
# (1018, 'Seven', ['Fincher(`', 'David', 'like'], ["')'s", 'part', 'three,'], True) False True ExtraTrees
# (1019, 'Aliens', ['`', "JamesCameron's", 'in'], ["'.", 'But', 'I'], True) False True ExtraTrees
# (1020, 'Independence Day', ['`', 'in', 'hear'], ["'.", "They're", 'uniqueducks'], True) False True ExtraTrees
# (1022, 'aesthetically', ['artfullymade,', 'is', "'"], ['pretty', 'like', 'David'], False) True False ExtraTrees
# (1032, 'Anastasia', ['', '', ''], ['a', 'reviewBy', 'Jeremiah'], True) False True ExtraTrees
# (1033, 'Anastasia', ['showingof', 'late', 'the'], ['at', 'one', 'of'], True) False True ExtraTrees
# (1034, 'Anastasia', ['digress.', 'I', 'but'], ['is', 'the', 'first'], True) False True ExtraTrees
# (1035, 'The Secret of Nimh', ['entertainment,including', 'animated', 'of'], [',', 'An', 'American'], True) False True ExtraTrees
# (1036, 'An American Tail', [',', 'Nimh', 'of'], [',', 'and', 'All'], True) False True ExtraTrees
# (1037, 'All Dogs Go To Heaven', ['and', ',', 'Tail'], [',just', 'to', 'name'], True) False True ExtraTrees
# (1040, 'The Black Cauldron', ['of', 'reminded', 'was'], ['a', 'bit,where', 'armies'], True) False True ExtraTrees
# (1041, 'Anastaisa', ['if', 'besurprised', 'would'], ['grosses', 'in', 'the'], True) False True ExtraTrees
# (1042, 'Alladin', ['in', 'parrot', 'The'], ['as', 'played', 'by'], True) False True ExtraTrees
# (1073, 'Resurrection', ['alliance."', 'uneasy', 'an'], ['\x12s"', 'action', 'sequences'], True) False True ExtraTrees
# (1097, '60% of ANASTASIA', ["You'llsee", '.', 'CANDLESHOE'], ['there.Dave', 'ThompsenEmail', ':'], False) True False ExtraTrees
# (1174, 'Blade Runner', ['when', 'was', 'outmid-day'], ['was', 'released.', 'Today'], True) False True ExtraTrees
# (1175, 'Alien Resurrection', ['-', 'further', 'any'], ['is', '_great_.', 'Webbies'], True) False True ExtraTrees
# (1176, 'English Patient', ['the', "Itisn't", 'rating.'], ['(but', 'maybe', 'there'], True) False True ExtraTrees
# (1177, 'Bride of Dracula', ['the', 'with', 'inlove'], ['(I', 'still', 'fall'], True) False True ExtraTrees
# (1178, 'Alien Resurrection', ['love', 'yagotta', 'then'], ['.', 'It', 'has'], True) False True ExtraTrees
# (1179, 'Zorro', ['for', 'was', 'lot'], ['.', 'Yes,', 'Zorro'], True) False True ExtraTrees
# (1180, 'Zorro', ['Yes,', '.', 'Zorro'], ['.', 'I', 'kept'], True) False True ExtraTrees
# (1191, 'Alien Resurrection', ['', '', ''], ['Director:', 'Jean-Pierre', 'JeunetStarring:'], True) False True ExtraTrees
# (1192, 'Alien 3', ['in', 'died', 'she'], ['.', 'But', 'those'], True) False True ExtraTrees
# (1193, 'AlienResurrection', ['that', 'thing', 'stuff.Another'], ['offers', 'that', 'the'], True) False True ExtraTrees
# (1194, 'Alien 3', ['After', 'now?', 'series'], [',', 'we', 'were'], True) False True ExtraTrees
# (1205, 'Anastasia', ['', '', ''], ['Directors:', 'Don', 'Bluth'], True) False True ExtraTrees
# (1215, 'front ofimpressionist backgrounds)Somehow,', ['in', 'dance', 'to'], ['the', '"', 'Magic'], False) True False ExtraTrees
# (1272, 'LOST CHILDREN .', ['OF', 'CITY', 'masterpiece'], ['His', 'strengths', 'are'], False) True False ExtraTrees
# (1298, 'second film, is', ['the', '(1986),', 'ALIENS'], ['a', 'classicas', 'well.'], False) True False ExtraTrees
# (1307, 'Maria', ['1', '9917.html-rwx------', '18:43'], ['None', '4465', 'Feb'], False) True False ExtraTrees
# (1308, '17 18:43', ['Feb', '4690', 'None'], ['9729.html-rwx------', '1', 'Maria'], False) True False ExtraTrees
# (1309, 'None 5915', ['Maria', '1', '9646.html-rwx------'], ['Feb', '17', '18:43'], False) True False ExtraTrees
# (1310, 'Maria None 4127', ['1', '8669.html-rwx------', '18:43'], ['Feb', '17', '18:43'], False) True False ExtraTrees
# (1311, '1', ['8005.html-rwx------', '18:43', '17'], ['Maria', 'None', '3234'], False) True False ExtraTrees
# (1312, '9494.html-rwx------', ['18:43', '17', 'Feb'], ['1', 'Maria', 'None'], False) True False ExtraTrees
# (1313, 'Feb 17', ['588', 'None', 'Maria'], ['18:43', '9915.html-rwx------', '1'], False) True False ExtraTrees
# (1314, 'None', ['Maria', '1', '9180.html-rwx------'], ['1695', 'Feb', '17'], False) True False ExtraTrees
# (1315, 'Feb', ['4042', 'None', 'Maria'], ['17', '18:43', '8157.html-rwx------'], False) True False ExtraTrees
# (1316, 'Maria', ['1', '9917.html-rwx------', '18:43'], ['None', '4465', 'Feb'], False) True False ExtraTrees

# %% [markdown]
# ### Prepare Set 3 and run ML models on Set 3

# %%
df_set3_1 = featureGen(set3)
df_set3_1.head(n=10)
# Out:
#      "'s  Alien Copyright Directed   Film  Maria Recommend Review Sequel  \
# 0  False  False     False    False  False  False     False  False  False
# 1  False  False     False    False  False  False     False  False  False
# 2  False  False     False    False  False  False     False  False  False
# 3  False  False     False    False  False  False     False  False  False
# 4  False  False     False    False  False  False     False  False  False
# 5  False  False     False    False  False  False     False  False  False
# 6  False  False     False    False  False  False     False  False  False
# 7  False  False     False    False  False  False     False  False  False
# 8  False  False     False    False  False  False     False  False  False
# 9  False  False     False    False  False  False     False  False  False
#
#   Starring    ...          @     II    III capitalLetter hasCueWords hasYear  \
# 0    False    ...      False  False  False         False       False   False
# 1    False    ...      False  False  False         False       False   False
# 2    False    ...      False  False  False         False       False   False
# 3    False    ...      False  False  False         False       False   False
# 4    False    ...      False  False  False         False       False   False
# 5    False    ...      False  False  False         False       False   False
# 6    False    ...      False  False  False         False       False   False
# 7    False    ...      False  False  False         False       False   False
# 8    False    ...      False  False  False         False       False   False
# 9    False    ...      False  False  False         False       False   False
#
#   hasYear_parenth isCap isPositive yearbyChar
# 0           False  True       True      False
# 1           False  True       True      False
# 2           False  True       True      False
# 3           False  True       True      False
# 4           False  True       True      False
# 5           False  True       True      False
# 6           False  True       True      False
# 7           False  True       True      False
# 8           False  True       True      False
# 9           False  True       True      False
#
# [10 rows x 38 columns]

# %%
X = df_set3_1.ix[:, df_set3_1.columns != 'isPositive'].values
y = np.ravel(df_set3_1[['isPositive']].values)

# %%
crossv = False
nfolds = 10

if crossv == True:
    result = MLmodels(X, y, nfolds, crossv)
else:
    (result,idlist) = MLmodels(X, y, nfolds,crossv)

# %%
result
# Out:
#                       r   r_macro  r_micro  r_weight         p   p_macro  \
# Decision Tree  0.975385  0.981377   0.9825    0.9825  0.981424  0.982326
# Logistic       0.981538  0.984453   0.9850    0.9850  0.981538  0.984453
# SVM            0.975385  0.981377   0.9825    0.9825  0.981424  0.982326
# Random Forest  0.981538  0.984453   0.9850    0.9850  0.981538  0.984453
# ExtraTrees     0.981538  0.984453   0.9850    0.9850  0.981538  0.984453
#
#                p_micro  p_weight        f1  f1_macro  f1_micro  f1_weight  \
# Decision Tree   0.9825  0.982495  0.978395  0.981845    0.9825   0.982491
# Logistic        0.9850  0.985000  0.981538  0.984453    0.9850   0.985000
# SVM             0.9825  0.982495  0.978395  0.981845    0.9825   0.982491
# Random Forest   0.9850  0.985000  0.981538  0.984453    0.9850   0.985000
# ExtraTrees      0.9850  0.985000  0.981538  0.984453    0.9850   0.985000
#
#                  accu
# Decision Tree  0.9825
# Logistic       0.9850
# SVM            0.9825
# Random Forest  0.9850
# ExtraTrees     0.9850

# %% [markdown]
# Based on our error analysis, we add in some more rules:

# %%
#Amendments to Feature Generation Based on Error Analysis

def isitcapitalized(testcase):
    """Is the label capitalized? Return True or False"""
    return testcase[1].isupper()

def capitalletter(testcase):
    """Is there a capital letter followed by white space or capital letter +/- followed by white space - movie grades. Return True or False"""
    combo = testcase[2] + testcase[3]
    joined = "".join(combo)
    gradesearch = re.compile(r"[A-Z]\s|[A-Z+]\s|[A-Z-]\s")
    if re.search(gradesearch, joined):
        return True
    else:
        return False
    
def yearbyChar(testcase):
    """Is there a year in parentheses followed by any word character? Return True or False"""
    combo = testcase[2] + testcase[3]
    joined = "".join(combo)
    yearcharsearch = re.compile(r"(\d\d\d\d)\w")
    if re.search(yearcharsearch, joined):
        return True
    else:
        return False
    
    
def isthereayear(testcase):
    """Is the YEAR (YYYY) format in the surrounding 3 words before and after? Return True or False"""
    combo = testcase[2] + testcase[3]
    joined = "".join(combo)
    yearsearch = re.compile(r"\d\d\d\d")
    if re.search(yearsearch, joined):
        return True
    else:
        return False
    
def isthereayear_parenth(testcase):
    """Is the YEAR (YYYY) format in the surrounding 3 words before and after? Return True or False"""
    combo = testcase[2] + testcase[3]
    joined = "".join(combo)
    yearsearch = re.compile(r"(\d\d\d\d)")
    if re.search(yearsearch, joined):
        return True
    else:
        return False    
    
def hasCueWords(testcase,cueword=None):
    """Are any of the cuewords we determined found in the surrounding text? Return True or False"""
    combo = testcase[2] + testcase[3]
    if cueword:
        for word in combo:
            if word == cueword:
                return True
    else:
        for word in combo:
            if word in cuewords:
                return True
    return False

def hasCueSymbols(testcase,cuesymbol=None):
    """Are any of the cuesymbols we determined found in the surrounding text? Return True or False"""
    combo = testcase[2] + testcase[3]
    #combo = combo.split(' ')
    if cuesymbol:
        for symb in combo:
            if symb == cuesymbol:
                return True
    else:
        for symb in cuesymbols:
            return True
    return False


def isPositive(testcase):
    """Is this a positive or negative example? Return True or False"""
    return testcase[-1]

def featureGen(cases):
    """This function brings together all of our feature generation functions and
    exports a pandas dataframe which can be fed into the ML classifiers"""
    #Set Key words and Key symbols
    cuewords = {'in':True, 'made':True, 'review':True, 'film':True, 'recommend':True, "showing":True, 
                'released':True, "The": True, "Alien": True, "onscreen": True, "by": True, "Film": True, "Review":True,
               'Copyright': True, 'Starring':True, 'Sequel': True, '"\'s': True, "Directed": True, "Maria": False, 
               'Recommend':True, 'recommend':True, 'by': True}
    cuesymbols = {'*':True, '(':True, ')':True ,'"':True, "'":True, ':':True, 'II':True, 'III':True, '***': True,
                 '****': True, '@':False}
    
    for cueword in cuewords:
        cuewords[cueword] = [hasCueWords(case, cueword) for case in cases]  
        
    for cuesymb in cuesymbols:
        cuesymbols[cuesymb] = [hasCueSymbols(case, cuesymb) for case in cases]   
        
    #Create subdataframes
    cuewords_df = pd.DataFrame(cuewords)
    cuesymbols_df = pd.DataFrame(cuesymbols)
    
    #Put it all together into master dataframe
    features = pd.DataFrame(
        {'hasYear':[isthereayear(case) for case in cases],
         'hasYear_parenth':[isthereayear_parenth(case) for case in cases],
         'yearbyChar': [yearbyChar(case) for case in cases],
         'isCap':[isitcapitalized(case) for case in cases],
         'hasCueWords':[hasCueWords(case, cuewords) for case in cases],    
         'capitalLetter':[capitalletter(case) for case in cases],
         'isPositive':[isPositive(case) for case in cases]
        }
    )
    df = pd.concat([cuewords_df, cuesymbols_df, features], axis=1)
    return(df)

# %% [markdown]
# After modifying the features based on the FP/FN misclassifications from set 2, we go back and run k-fold CV on set 1:

# %%
df_set1_new = featureGen(set1)
df_set1_new.head(n=10)
# Out:
#      "'s  Alien Copyright Directed   Film  Maria Recommend Review Sequel  \
# 0  False  False     False    False  False  False     False  False  False
# 1  False  False     False    False  False  False     False  False  False
# 2  False  False     False    False  False  False     False  False  False
# 3  False  False     False    False  False  False     False  False  False
# 4  False  False     False    False  False  False     False  False  False
# 5  False  False     False    False  False  False     False  False  False
# 6  False  False     False    False  False  False     False  False  False
# 7  False  False     False    False  False  False     False  False  False
# 8  False  False     False    False  False  False     False  False  False
# 9  False  False     False    False  False  False     False  False  False
#
#   Starring    ...          @     II    III capitalLetter hasCueWords hasYear  \
# 0    False    ...      False  False  False         False       False   False
# 1    False    ...      False  False  False         False       False    True
# 2    False    ...      False  False  False         False       False   False
# 3    False    ...      False  False  False         False       False   False
# 4    False    ...      False  False  False         False       False   False
# 5    False    ...      False  False  False         False       False   False
# 6    False    ...      False  False  False         False       False   False
# 7    False    ...      False  False  False         False       False   False
# 8    False    ...      False  False  False         False       False   False
# 9    False    ...      False  False  False         False       False   False
#
#   hasYear_parenth  isCap isPositive yearbyChar
# 0           False   True       True      False
# 1            True   True       True       True
# 2           False   True       True      False
# 3           False   True       True      False
# 4           False   True       True      False
# 5           False   True       True      False
# 6           False   True       True      False
# 7           False  False      False      False
# 8           False  False      False      False
# 9           False  False      False      False
#
# [10 rows x 38 columns]

# %%
X = df_set1_new.ix[:, df_set1_new.columns != 'isPositive'].values
y = np.ravel(df_set1_new[['isPositive']].values)

# %%
crossv = True
nfolds = 10

if crossv == True:
    result = MLmodels(X, y, nfolds, crossv)
else:
    (result,idlist) = MLmodels(X, y, nfolds,crossv)

# %%
result
# Out:
#                       r   r_macro   r_micro  r_weight         p   p_macro  \
# Decision Tree  1.000000  0.994444  0.994505  0.994505  0.989247  0.994624
# Decision Tree  1.000000  0.994318  0.994505  0.994505  0.989474  0.994737
# Decision Tree  1.000000  0.995098  0.994505  0.994505  0.987654  0.993827
# Decision Tree  1.000000  0.987654  0.989011  0.989011  0.980583  0.990291
# Decision Tree  1.000000  0.994382  0.994505  0.994505  0.989362  0.994681
# Decision Tree  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# Decision Tree  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# Decision Tree  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# Decision Tree  1.000000  0.994048  0.994475  0.994475  0.989796  0.994898
# Decision Tree  1.000000  0.996032  0.994475  0.994475  0.982143  0.991071
# Logistic       1.000000  0.994444  0.994505  0.994505  0.989247  0.994624
# Logistic       0.989362  0.988999  0.989011  0.989011  0.989362  0.988999
# Logistic       1.000000  0.995098  0.994505  0.994505  0.987654  0.993827
# Logistic       1.000000  0.987654  0.989011  0.989011  0.980583  0.990291
# Logistic       1.000000  0.994382  0.994505  0.994505  0.989362  0.994681
# Logistic       1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# Logistic       1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# Logistic       1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# Logistic       0.989691  0.988893  0.988950  0.988950  0.989691  0.988893
# Logistic       1.000000  0.996032  0.994475  0.994475  0.982143  0.991071
# SVM            1.000000  0.994444  0.994505  0.994505  0.989247  0.994624
# SVM            1.000000  0.994318  0.994505  0.994505  0.989474  0.994737
# SVM            1.000000  0.995098  0.994505  0.994505  0.987654  0.993827
# SVM            1.000000  0.987654  0.989011  0.989011  0.980583  0.990291
# SVM            1.000000  0.994382  0.994505  0.994505  0.989362  0.994681
# SVM            1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# SVM            1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# SVM            1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# SVM            1.000000  0.994048  0.994475  0.994475  0.989796  0.994898
# SVM            1.000000  0.996032  0.994475  0.994475  0.982143  0.991071
# Random Forest  1.000000  0.994444  0.994505  0.994505  0.989247  0.994624
# Random Forest  0.989362  0.988999  0.989011  0.989011  0.989362  0.988999
# Random Forest  1.000000  0.995098  0.994505  0.994505  0.987654  0.993827
# Random Forest  1.000000  0.987654  0.989011  0.989011  0.980583  0.990291
# Random Forest  1.000000  0.994382  0.994505  0.994505  0.989362  0.994681
# Random Forest  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# Random Forest  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# Random Forest  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# Random Forest  0.989691  0.988893  0.988950  0.988950  0.989691  0.988893
# Random Forest  1.000000  0.996032  0.994475  0.994475  0.982143  0.991071
# ExtraTrees     1.000000  0.994444  0.994505  0.994505  0.989247  0.994624
# ExtraTrees     0.989362  0.988999  0.989011  0.989011  0.989362  0.988999
# ExtraTrees     1.000000  0.995098  0.994505  0.994505  0.987654  0.993827
# ExtraTrees     1.000000  0.987654  0.989011  0.989011  0.980583  0.990291
# ExtraTrees     1.000000  0.994382  0.994505  0.994505  0.989362  0.994681
# ExtraTrees     1.000000  0.993750  0.994475  0.994475  0.990196  0.995098
# ExtraTrees     1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# ExtraTrees     1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# ExtraTrees     0.989691  0.988893  0.988950  0.988950  0.989691  0.988893
# ExtraTrees     1.000000  0.996032  0.994475  0.994475  0.982143  0.991071
#
#                 p_micro  p_weight        f1  f1_macro  f1_micro  f1_weight  \
# Decision Tree  0.994505  0.994565  0.994595  0.994504  0.994505   0.994505
# Decision Tree  0.994505  0.994563  0.994709  0.994497  0.994505   0.994504
# Decision Tree  0.994505  0.994573  0.993789  0.994431  0.994505   0.994509
# Decision Tree  0.989011  0.989224  0.990196  0.988848  0.989011   0.988996
# Decision Tree  0.994505  0.994564  0.994652  0.994501  0.994505   0.994505
# Decision Tree  1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# Decision Tree  1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# Decision Tree  1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# Decision Tree  0.994475  0.994532  0.994872  0.994442  0.994475   0.994473
# Decision Tree  0.994475  0.994574  0.990991  0.993503  0.994475   0.994489
# Logistic       0.994505  0.994565  0.994595  0.994504  0.994505   0.994505
# Logistic       0.989011  0.989011  0.989362  0.988999  0.989011   0.989011
# Logistic       0.994505  0.994573  0.993789  0.994431  0.994505   0.994509
# Logistic       0.989011  0.989224  0.990196  0.988848  0.989011   0.988996
# Logistic       0.994505  0.994564  0.994652  0.994501  0.994505   0.994505
# Logistic       1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# Logistic       1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# Logistic       1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# Logistic       0.988950  0.988950  0.989691  0.988893  0.988950   0.988950
# Logistic       0.994475  0.994574  0.990991  0.993503  0.994475   0.994489
# SVM            0.994505  0.994565  0.994595  0.994504  0.994505   0.994505
# SVM            0.994505  0.994563  0.994709  0.994497  0.994505   0.994504
# SVM            0.994505  0.994573  0.993789  0.994431  0.994505   0.994509
# SVM            0.989011  0.989224  0.990196  0.988848  0.989011   0.988996
# SVM            0.994505  0.994564  0.994652  0.994501  0.994505   0.994505
# SVM            1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# SVM            1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# SVM            1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# SVM            0.994475  0.994532  0.994872  0.994442  0.994475   0.994473
# SVM            0.994475  0.994574  0.990991  0.993503  0.994475   0.994489
# Random Forest  0.994505  0.994565  0.994595  0.994504  0.994505   0.994505
# Random Forest  0.989011  0.989011  0.989362  0.988999  0.989011   0.989011
# Random Forest  0.994505  0.994573  0.993789  0.994431  0.994505   0.994509
# Random Forest  0.989011  0.989224  0.990196  0.988848  0.989011   0.988996
# Random Forest  0.994505  0.994564  0.994652  0.994501  0.994505   0.994505
# Random Forest  1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# Random Forest  1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# Random Forest  1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# Random Forest  0.988950  0.988950  0.989691  0.988893  0.988950   0.988950
# Random Forest  0.994475  0.994574  0.990991  0.993503  0.994475   0.994489
# ExtraTrees     0.994505  0.994565  0.994595  0.994504  0.994505   0.994505
# ExtraTrees     0.989011  0.989011  0.989362  0.988999  0.989011   0.989011
# ExtraTrees     0.994505  0.994573  0.993789  0.994431  0.994505   0.994509
# ExtraTrees     0.989011  0.989224  0.990196  0.988848  0.989011   0.988996
# ExtraTrees     0.994505  0.994564  0.994652  0.994501  0.994505   0.994505
# ExtraTrees     0.994475  0.994529  0.995074  0.994392  0.994475   0.994471
# ExtraTrees     1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# ExtraTrees     1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# ExtraTrees     0.988950  0.988950  0.989691  0.988893  0.988950   0.988950
# ExtraTrees     0.994475  0.994574  0.990991  0.993503  0.994475   0.994489
#
#                    accu     score
# Decision Tree  0.994505  0.994505
# Decision Tree  0.994505  0.994505
# Decision Tree  0.994505  0.994505
# Decision Tree  0.989011  0.989011
# Decision Tree  0.994505  0.994505
# Decision Tree  1.000000  1.000000
# Decision Tree  1.000000  1.000000
# Decision Tree  1.000000  1.000000
# Decision Tree  0.994475  0.994475
# Decision Tree  0.994475  0.994475
# Logistic       0.994505  0.994505
# Logistic       0.989011  0.989011
# Logistic       0.994505  0.994505
# Logistic       0.989011  0.989011
# Logistic       0.994505  0.994505
# Logistic       1.000000  1.000000
# Logistic       1.000000  1.000000
# Logistic       1.000000  1.000000
# Logistic       0.988950  0.988950
# Logistic       0.994475  0.994475
# SVM            0.994505  0.994505
# SVM            0.994505  0.994505
# SVM            0.994505  0.994505
# SVM            0.989011  0.989011
# SVM            0.994505  0.994505
# SVM            1.000000  1.000000
# SVM            1.000000  1.000000
# SVM            1.000000  1.000000
# SVM            0.994475  0.994475
# SVM            0.994475  0.994475
# Random Forest  0.994505  0.994505
# Random Forest  0.989011  0.989011
# Random Forest  0.994505  0.994505
# Random Forest  0.989011  0.989011
# Random Forest  0.994505  0.994505
# Random Forest  1.000000  1.000000
# Random Forest  1.000000  1.000000
# Random Forest  1.000000  1.000000
# Random Forest  0.988950  0.988950
# Random Forest  0.994475  0.994475
# ExtraTrees     0.994505  0.994505
# ExtraTrees     0.989011  0.989011
# ExtraTrees     0.994505  0.994505
# ExtraTrees     0.989011  0.989011
# ExtraTrees     0.994505  0.994505
# ExtraTrees     0.994475  0.994475
# ExtraTrees     1.000000  1.000000
# ExtraTrees     1.000000  1.000000
# ExtraTrees     0.988950  0.988950
# ExtraTrees     0.994475  0.994475

# %% [markdown]
# We see improvement! Let us now finally run this on set 3:

# %% [markdown]
# ### Prepare Set 3 and run ML Models on Set 3 (final test set)

# %%
df_set3 = featureGen(set3)
df_set3.tail(n=10)
# Out:
#         "'s  Alien Copyright Directed   Film  Maria Recommend Review Sequel  \
# 1590  False  False     False    False  False  False     False  False  False
# 1591  False  False     False    False  False  False     False  False  False
# 1592  False  False     False    False  False  False     False  False  False
# 1593  False  False     False    False  False  False     False  False  False
# 1594  False  False     False    False  False  False     False  False  False
# 1595  False  False     False    False  False  False     False  False  False
# 1596  False  False     False    False  False  False     False  False  False
# 1597  False  False     False    False  False  False     False  False  False
# 1598  False  False     False    False  False  False     False  False  False
# 1599  False  False     False    False  False  False     False  False  False
#
#      Starring    ...          @     II    III capitalLetter hasCueWords  \
# 1590    False    ...      False  False  False         False       False
# 1591    False    ...      False  False  False         False       False
# 1592    False    ...      False  False  False         False       False
# 1593    False    ...      False  False  False         False       False
# 1594    False    ...      False  False  False         False       False
# 1595    False    ...      False  False  False         False       False
# 1596    False    ...      False  False  False         False       False
# 1597    False    ...      False  False  False         False       False
# 1598    False    ...      False  False  False         False       False
# 1599    False    ...      False  False  False         False       False
#
#      hasYear hasYear_parenth  isCap isPositive yearbyChar
# 1590   False           False  False      False      False
# 1591   False           False  False      False      False
# 1592   False           False  False      False      False
# 1593   False           False   True      False      False
# 1594   False           False  False      False      False
# 1595   False           False  False      False      False
# 1596   False           False  False      False      False
# 1597   False           False  False      False      False
# 1598   False           False  False      False      False
# 1599   False           False  False      False      False
#
# [10 rows x 38 columns]

# %%
X = df_set3.ix[:, df_set3.columns != 'isPositive'].values
y = np.ravel(df_set3[['isPositive']].values)

# %%
crossv = False
nfolds = 10

if crossv == True:
    result = MLmodels(X, y, nfolds, crossv)
else:
    (result,idlist) = MLmodels(X, y, nfolds,crossv)

# %%
result
# Out:
#                       r   r_macro   r_micro  r_weight         p   p_macro  \
# Decision Tree  0.975385  0.981377  0.982500  0.982500  0.981424  0.982326
# Logistic       0.981538  0.984453  0.985000  0.985000  0.981538  0.984453
# SVM            0.975385  0.981377  0.982500  0.982500  0.981424  0.982326
# Random Forest  0.980000  0.983684  0.984375  0.984375  0.981510  0.983920
# ExtraTrees     0.981538  0.984453  0.985000  0.985000  0.981538  0.984453
#
#                 p_micro  p_weight        f1  f1_macro  f1_micro  f1_weight  \
# Decision Tree  0.982500  0.982495  0.978395  0.981845  0.982500   0.982491
# Logistic       0.985000  0.985000  0.981538  0.984453  0.985000   0.985000
# SVM            0.982500  0.982495  0.978395  0.981845  0.982500   0.982491
# Random Forest  0.984375  0.984372  0.980754  0.983802  0.984375   0.984373
# ExtraTrees     0.985000  0.985000  0.981538  0.984453  0.985000   0.985000
#
#                    accu
# Decision Tree  0.982500
# Logistic       0.985000
# SVM            0.982500
# Random Forest  0.984375
# ExtraTrees     0.985000

# %% [markdown]
# On our final testing set, we were able to reach the required precision and recall. We identify our strongest classifier to be the logistic regression classifier, followed by the random forest. Looking above, we find that this holds true across the sets.
